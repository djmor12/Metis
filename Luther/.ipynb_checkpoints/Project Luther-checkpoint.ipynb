# %% [markdown]
# # Project Luther
#
# The goal of project luther is to create a linear regression model for supervised machine learning. We also need to incorporate web scrapping into the project to get practice finding what we need.
#
# I will be pulling data from Ted.com.  Specifically, I will be grabbing view count, tags and the published date.  We also will initiate our proxies here, and I will tell why we need them when they are employed below.
#
# Packages needed for this portion:
#  * Pandas
#  * Numpy
#  * BeautifulSoup
#  * Requests
#  * Regex

# %%
import requests as rq
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as soup
import re
import time
import csv

# %%
#Proxies need to be changed each run until data is collected!
proxies = {
    "http": 'http://108.61.87.166:8080', 
    "https": 'http://108.61.87.166:8080'
}
prox2 = {
    "http": 'http://144.202.108.231:8888', 
    "https": 'http://144.202.108.231:8888'
}
prox3 = {
    "http": 'http://52.229.52.86:3128', 
    "https": 'http://52.229.52.86:3128'
}
prox4 = {
    "http": 'http://35.169.210.105:3389', 
    "https": 'http://35.169.210.105:3389'
}
base = 'https://www.ted.com'
start_url = 'https://www.ted.com/talks'

response = rq.get(start_url)

# %%
page = response.text
mainpage = soup(page,"lxml")

# %%
talks = re.compile('/talks/')
views = re.compile("Related Tags")

# %%
def GetVid(mainlist):
    vid_str = []
    l = len(mainlist)-1
    for i in range(0,l,2):
        new_str = str(mainlist[i])
        vid_str.append(new_str.split('"')[5])
    return vid_str

# %%
#Getting all cases where we have a /talks url
list_1 = mainpage.find_all(href=talks)

# %%
#Pulling a list of all video end url links
lnk_list = GetVid(list_1)
lnk_list
# Out:
# ['/talks/tracee_ellis_ross_a_woman_s_fury_holds_lifetimes_of_wisdom',
#  '/talks/dayo_ogunyemi_visions_of_africa_s_future_from_african_filmmakers',
#  '/talks/clemantine_wamariya_war_and_what_comes_after',
#  '/talks/gwynne_shotwell_spacex_s_plan_to_fly_you_across_the_globe_in_30_minutes',
#  '/talks/diane_wolk_rogers_a_parkland_teacher_s_homework_for_us_all',
#  '/talks/zachary_r_wood_why_it_s_worth_listening_to_people_we_disagree_with',
#  '/talks/nancy_rabalais_the_dead_zone_of_the_gulf_of_mexico',
#  '/talks/mark_tyndall_the_harm_reduction_model_of_drug_addiction_treatment',
#  '/talks/hannah_burckstummer_a_printable_flexible_organic_solar_cell',
#  '/talks/yasin_kakande_what_s_missing_in_the_global_debate_over_refugees',
#  '/talks/robin_steinberg_what_if_we_ended_the_injustice_of_bail',
#  '/talks/jaron_lanier_how_we_need_to_remake_the_internet',
#  '/talks/malika_whitley_how_the_arts_help_homeless_youth_heal_and_build',
#  '/talks/lera_boroditsky_how_language_shapes_the_way_we_think',
#  '/talks/jose_andres_how_a_team_of_chefs_fed_puerto_rico_after_hurricane_maria',
#  '/talks/tara_houska_the_standing_rock_resistance_and_our_fight_for_indigenous_rights',
#  '/talks/kasiva_mutua_how_i_use_the_drum_to_tell_my_story',
#  '/talks/danny_hillis_exploring_options_for_solar_geoengineering',
#  '/talks/andrew_dent_to_eliminate_waste_we_need_to_rediscover_thrift',
#  '/talks/drew_philp_my_500_house_in_detroit_and_the_neighbors_who_helped_me_rebuild_it',
#  '/talks/irina_kareva_math_can_help_uncover_cancer_s_secrets',
#  '/talks/raphael_arar_how_we_can_teach_computers_to_make_sense_of_our_emotions',
#  '/talks/christian_picciolini_my_descent_into_america_s_neo_nazi_movement_and_how_i_got_out',
#  '/talks/judith_heumann_our_fight_for_disability_rights_and_why_we_re_not_done_yet',
#  '/talks/leo_igwe_why_i_choose_humanism_over_faith',
#  '/talks/ndidi_nwuneli_the_role_of_faith_and_belief_in_modern_africa',
#  '/talks/erica_stone_academic_research_is_publicly_funded_why_isn_t_it_publicly_available',
#  '/talks/mennat_el_ghalid_how_fungi_recognize_and_infect_plants',
#  '/talks/vikram_sharma_how_quantum_physics_can_make_encryption_stronger',
#  '/talks/matthias_mullenbeck_what_if_we_paid_doctors_to_keep_people_healthy',
#  '/talks/amishi_jha_how_to_tame_your_wandering_mind',
#  '/talks/sauti_sol_the_rhythm_of_afrobeat',
#  '/talks/eve_abrams_the_human_stories_behind_mass_incarceration',
#  '/talks/vittorio_loreto_need_a_new_idea_start_at_the_edge_of_what_is_known',
#  '/talks/soka_moses_for_survivors_of_ebola_the_crisis_isn_t_over',
#  '/talks/bob_stein_a_rite_of_passage_for_late_life']

# %% [markdown]
# ## Creating a list for all ted talks
#
# The ted talks pagination has the url /talks?page=3, therefore we can simplify this to a 'talks?page=' + a list of numbers from 2 to 77 in '77'.  We need to cycle through group of proxies to avoid getting blocked from the site.  We never get permanently 'blocked', but we can get blocked temporarily.

# %%
page_lst = [str(i) for i in range(2,78)]
mid = '/talks?page='

# %%
url_list = [base+mid+i for i in page_lst]
url_list.insert(0,'https://www.ted.com/talks')

# %%
def GetVidLst(vurl, prox = None):
    resp = rq.get(vurl, prox)
    ppage = resp.text
    vidpage = soup(ppage,"lxml")
    vlist = vidpage.find_all(href=talks)
    vid_lnk_list = GetVid(vlist)
    return vid_lnk_list

# %%
#Creating a list of all the ted vides
fin = []
count=0
proxy = None
for i in url_list:
    count+=1
    fin +=GetVidLst(i, proxy)
    time.sleep(5)
    if count == 30 or count == 60 or count == 90 or count == 120:
        time.sleep(10)
        if count ==30:proxy = proxies
        if count ==60: proxy = prox2
        if count ==90: proxy = prox3
        if count ==120: 
            proxy = None 
            count = 10

# %%
fin[0]
# Out:
# '/talks/tracee_ellis_ross_a_woman_s_fury_holds_lifetimes_of_wisdom'

# %% [markdown]
# ## Create Ted Talk Dictionary
#
# Now that we have our list of all the videos, we are going to create a dictionary with the following format:
# {'Title':\['Views', \['Tags'\], Date Posted\]}.
#
# To accomplish this, I first did all the work on a single page, then I will create functions for each step and call them in a for loop over the list 'fin'.

# %%
#Changes views string to an integer
def view_to_int(viewstring):
    viewstring= viewstring.replace('\n', '').replace(',', '')
    return int(viewstring)

# %%
def get_Views(site_text):
    views_list = []
    viewint=0
    views = site_text.find_all(class_=" d:n f-w:700 f:.9 f:1@xxl c:white ")
    str_list2 = str(views).split('<span')[1].split('\t')
    viewint = view_to_int(str_list2[5])
    return viewint

# %%
def get_ratings(vidpage):
    super_comment = vidpage.find_all(text = re.compile('ratings'))
    the_max = max(super_comment, key=len)
    super_comment=the_max.split('ratings')
    super_comment = super_comment[1].split("\"name\":")
    super_comment
    target_ratings = ['Confusing', 'Funny',  'Unconvincing', 'Longwinded', 'Inspiring', 'Fascinating', 'Jaw-dropping']
    count = 0
    rate_dict = {}
    for i in super_comment:
        if count in [2,5,8,9,10,11,12]:
            str_list = i.split(",")
            rate_name = str_list[0].replace("\"",'')
            rate_count = str_list[1].replace('\"count\":','').split('}')[0]
            rate_dict[rate_name] = float(rate_count)
        count+=1
    return rate_dict

# %%
#Cleaning up site text to get tags
def Cleanup(site_text):
    super_comment = site_text.find_all(text = re.compile('tag'))
    the_max = max(super_comment, key=len)
    super_comment=the_max.split('tags')
    super_comment = super_comment[1].split("\"")
    tag=[]
    tag =[super_comment[i] for i in range(2,9,2)]
    return tag

# %%
#Cleaning up site text to get tags
def Cleanup(site_text):
    super_comment = site_text.find_all(text = re.compile('ratings'))
    the_max = max(super_comment, key=len)
    super_comment=the_max.split('ratings')
    super_comment = super_comment[1].split("\"")
    tag=[]
    tag =[super_comment[i] for i in range(2,9,2)]
    return tag

# %%
def getDate(site_text):
    super_comment = str(site_text.find_all(text = re.compile('recorded_at')))
    inter = re.findall(re.compile('"recorded_at"'), super_comment)
    intermed = super_comment.split(inter[0])
    intermed = intermed[1].split(':')
    date = intermed[1].replace('T00', '').replace('"', "")
    return date

# %%
#Creating a list of all the ted vides
data = {}
count=0
tot_views=[]
proxy = prox4
for i in fin:
    time.sleep(15)
    count+=1
    curl = base+i
    response = rq.get(curl, proxy)
    web_page = response.text
    webpage = soup(web_page,"lxml")
    date = getDate(webpage)
    tag_list = Cleanup(webpage)
    tot_views = get_Views(webpage)
    ratings = get_ratings(webpage)
    data[i] = [date,tot_views,tag_list,ratings]
    if count == 20 or count == 40 or count == 60 or count == 80:
        time.sleep(10)
        if count ==20:proxy = proxies
        if count ==40: proxy = prox2
        if count ==60: proxy = prox4
        if count ==80: 
            proxy = prox3
            count = 0
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-59-c7208926616b> in <module>()
#      11     web_page = response.text
#      12     webpage = soup(web_page,"lxml")
# ---> 13     date = getDate(webpage)
#      14     tag_list = Cleanup(webpage)
#      15     tot_views = get_Views(webpage)
#
# <ipython-input-55-a5269f793306> in getDate(site_text)
#       2     super_comment = str(site_text.find_all(text = re.compile('recorded_at')))
#       3     inter = re.findall(re.compile('"recorded_at"'), super_comment)
# ----> 4     intermed = super_comment.split(inter[0])
#       5     intermed = intermed[1].split(':')
#       6     date = intermed[1].replace('T00', '').replace('"', "")
#
# IndexError: list index out of range

# %%
len(data)
# Out:
# 26

# %%
#Writing a pickle file
import pickle

with open('my_data.pkl', 'wb') as picklefile:
    pickle.dump(data, picklefile)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-fea4e090ce8b> in <module>()
#       3
#       4 with open('my_data.pkl', 'wb') as picklefile:
# ----> 5     pickle.dump(data, picklefile)
#
# NameError: name 'data' is not defined

# %%
#reading a pickle file
with open("my_data.pkl", 'rb') as picklefile: 
    my_old_data = pickle.load(picklefile)

# %% [markdown]
# ## To Pandas
#
# Now that we have our dictionary of values, we are changing it to a pandas dataframe for easier manipulation.
#
# There will then be some prelimnary exploring to see if it is formatted correctly or if more manipulation is needed.

# %%
my_old_data
# Out:
# {'/talks/adam_alter_why_our_screens_make_us_less_happy': ['2017-04-24',
#   2915234,
#   ['Addiction', 'computers', 'interface design', 'psychology']],
#  '/talks/adong_judith_how_i_use_art_to_bridge_misunderstanding': ['2017-08-27',
#   540027,
#   ['Africa', 'TED Fellows', 'activism', 'art']],
#  '/talks/alastair_gray_how_fake_handbags_fund_terrorism_and_organized_crime': ['2017-11-14',
#   1127728,
#   ['business', 'corruption', 'crime', 'terrorism']],
#  '/talks/alexander_wagner_what_really_motivates_people_to_be_honest_in_business': ['2016-11-11',
#   1336721,
#   ['TEDx', 'business', 'corruption', 'economics']],
#  '/talks/alexis_charpentier_how_record_collectors_find_lost_music_and_preserve_our_cultural_heritage': ['2016-11-12',
#   752230,
#   ['TEDx', 'art', 'culture', 'music']],
#  '/talks/alvin_irby_how_to_inspire_every_child_to_be_a_lifelong_reader': ['2017-11-28',
#   774478,
#   ['TED Residency', 'children', 'education', 'identity']],
#  '/talks/amar_inamdar_the_thrilling_potential_for_off_grid_solar_energy': ['2017-08-27',
#   1036766,
#   ['Africa', 'electricity', 'energy', 'global development']],
#  '/talks/ameenah_gurib_fakim_an_interview_with_mauritius_s_first_female_president': ['2017-08-27',
#   854899,
#   ['Africa', 'biodiversity', 'creativity', 'faith']],
#  '/talks/amel_karboul_the_global_learning_crisis_and_what_to_do_about_it': ['2017-10-04',
#   1374746,
#   ['Africa', 'children', 'education', 'future']],
#  '/talks/amishi_jha_how_to_tame_your_wandering_mind': ['2017-03-17',
#   1098977,
#   ['TEDx', 'brain', 'science', 'ratings']],
#  '/talks/amit_kalra_3_creative_ways_to_fix_fashion_s_waste_problem': ['2017-11-14',
#   721631,
#   ['business', 'creativity', 'design', 'environment']],
#  '/talks/anab_jain_why_we_need_to_imagine_different_futures': ['2017-04-24',
#   1526252,
#   ['AI', 'algorithm', 'cities', 'climate change']],
#  '/talks/andrew_dent_to_eliminate_waste_we_need_to_rediscover_thrift': ['2017-11-16',
#   560470,
#   ['creativity', 'design', 'future', 'innovation']],
#  '/talks/angela_wang_how_china_is_changing_the_future_of_shopping': ['2017-10-04',
#   1351113,
#   ['Internet', 'business', 'china', 'future']],
#  '/talks/anika_paulson_how_i_found_myself_through_music': ['2017-04-24',
#   1010825,
#   ['TED-Ed', 'guitar', 'live music', 'music']],
#  '/talks/anil_seth_how_your_brain_hallucinates_your_conscious_reality': ['2017-04-24',
#   4638160,
#   ['brain', 'cognitive science', 'humanity', 'mind']],
#  '/talks/anindya_kundu_the_boost_students_need_to_overcome_obstacles': ['2017-06-06',
#   1328960,
#   ['TED Residency', 'education', 'personal growth', 'sociology']],
#  '/talks/anjali_kumar_my_failed_mission_to_find_god_and_what_i_found_instead': ['2017-11-02',
#   1386872,
#   ['God', 'community', 'faith', 'happiness']],
#  '/talks/anjan_chatterjee_how_your_brain_decides_what_is_beautiful': ['2016-11-30',
#   1992599,
#   ['TEDMED', 'beauty', 'brain', 'cognitive science']],
#  '/talks/anjan_sundaram_why_i_risked_my_life_to_expose_a_government_massacre': ['2017-04-24',
#   952677,
#   ['Africa', 'TED Fellows', 'corruption', 'journalism']],
#  '/talks/anna_heringer_the_warmth_and_wisdom_of_mud_buildings': ['2017-04-24',
#   992506,
#   ['architecture', 'design', 'engineering', 'environment']],
#  '/talks/anna_rosling_ronnlund_see_how_the_rest_of_the_world_lives_organized_by_income': ['2017-04-24',
#   1196935,
#   ['data', 'global issues', 'humanity', 'photography']],
#  '/talks/anne_lamott_12_truths_i_learned_from_life_and_writing': ['2017-04-24',
#   2543842,
#   ['Christianity', 'God', 'aging', 'art']],
#  '/talks/anne_madden_meet_the_microscopic_life_in_your_home_and_on_your_face': ['2017-04-24',
#   1205061,
#   ['bacteria', 'biology', 'biomechanics', 'biotech']],
#  '/talks/arik_hartmann_our_treatment_of_hiv_has_advanced_why_hasn_t_the_stigma_changed': ['2016-09-10',
#   857343,
#   ['HIV', 'Human body', 'TEDx', 'activism']],
#  '/talks/armando_azua_bustos_the_most_martian_place_on_earth': ['2017-04-24',
#   1021448,
#   ['Mars', 'South America', 'TED Fellows', 'astrobiology']],
#  '/talks/ashton_applewhite_let_s_end_ageism': ['2017-04-24',
#   1284160,
#   ['aging', 'humanity', 'identity', 'inequality']],
#  '/talks/atul_gawande_want_to_get_great_at_something_get_a_coach': ['2017-04-24',
#   1413287,
#   ['Surgery', 'collaboration', 'goal-setting', 'life']],
#  '/talks/augie_picado_the_real_reason_manufacturing_jobs_are_disappearing': ['2017-07-20',
#   1540686,
#   ['business', 'capitalism', 'collaboration', 'economics']],
#  '/talks/azim_khamisa_and_ples_felix_what_comes_after_tragedy_forgiveness': ['2017-11-01',
#   907169,
#   ['activism', 'children', 'communication', 'community']],
#  '/talks/benjamin_grant_what_it_feels_like_to_see_earth_from_space': ['2017-04-07',
#   1187765,
#   ['TEDx', 'art', 'climate change', 'environment']],
#  '/talks/beth_malone_how_my_dad_s_dementia_changed_my_idea_of_death_and_life': ['2017-06-06',
#   1062046,
#   ['TED Residency', 'death', 'disease', 'family']],
#  '/talks/bhu_srinivasan_capitalism_isn_t_an_ideology_it_s_an_operating_system': ['2017-10-17',
#   848113,
#   ['business', 'capitalism', 'drones', 'economics']],
#  '/talks/bill_bernat_how_to_connect_with_depressed_friends': ['2017-11-04',
#   1096818,
#   ['TEDx', 'communication', 'compassion', 'depression']],
#  '/talks/bob_inglis_american_bipartisan_politics_can_be_saved_here_s_how': ['2017-11-18',
#   754931,
#   ['TEDx', 'United States', 'climate change', 'collaboration']],
#  '/talks/bob_stein_a_rite_of_passage_for_late_life': ['2017-11-28',
#   627605,
#   ['TED Residency', 'aging', 'communication', 'culture']],
#  '/talks/caitlin_quattromani_and_lauran_arledge_how_our_friendship_survives_our_opposing_politics': ['2017-07-08',
#   1014428,
#   ['TEDx', 'communication', 'friendship', 'politics']],
#  '/talks/carlos_bautista_the_awful_logic_of_land_mines_and_an_app_that_helps_people_avoid_them': ['2017-06-06',
#   887411,
#   ['South America', 'TED Residency', 'communication', 'innovation']],
#  '/talks/caroline_weaver_why_the_pencil_is_perfect': ['2018-03-15',
#   187643,
#   ['design', 'history', 'industrial design', 'writing']],
#  '/talks/carolyn_bertozzi_what_the_sugar_coating_on_your_cells_is_trying_to_tell_you': ['2016-04-24',
#   1083051,
#   ['biology', 'biomechanics', 'cancer', 'chemistry']],
#  '/talks/cathy_o_neil_the_era_of_blind_faith_in_big_data_must_end': ['2017-04-24',
#   1173672,
#   ['algorithm', 'data', 'inequality', 'marketing']],
#  '/talks/chance_coughenour_how_your_pictures_can_help_reclaim_lost_history': ['2016-06-08',
#   831433,
#   ['TEDx', 'ancient world', 'archaeology', 'conservation']],
#  '/talks/chetan_bhatt_dare_to_refuse_the_origin_myths_that_claim_who_you_are': ['2015-04-24',
#   1260759,
#   ['TEDx', 'community', 'humanity', 'identity']],
#  '/talks/cheyenne_cochrane_a_celebration_of_natural_hair': ['2016-11-19',
#   1282166,
#   ['TEDx', 'beauty', 'fashion', 'identity']],
#  '/talks/chika_ezeanya_esiobu_how_africa_can_use_its_traditional_knowledge_to_make_progress': ['2017-08-27',
#   1048792,
#   ['Africa', 'agriculture', 'creativity', 'culture']],
#  '/talks/chris_nowinski_can_i_have_your_brain_a_quest_for_truth_on_concussions_cte': ['2017-11-18',
#   646836,
#   ['TEDx', 'activism', 'brain', 'education']],
#  '/talks/chris_sheldrick_a_precise_three_word_address_for_every_place_on_earth': ['2017-08-27',
#   1199056,
#   ['communication', 'cooperation', 'global development', 'infrastructure']],
#  '/talks/christen_reighter_i_don_t_want_children_stop_telling_me_i_ll_change_my_mind': ['2016-10-28',
#   1657311,
#   ['TEDx', 'children', 'family', 'identity']],
#  '/talks/christian_benimana_the_next_generation_of_african_architects_and_designers': ['2017-08-27',
#   843817,
#   ['Africa', 'architecture', 'climate change', 'collaboration']],
#  '/talks/christian_picciolini_my_descent_into_america_s_neo_nazi_movement_and_how_i_got_out': ['2017-11-10',
#   631302,
#   ['TEDx', 'United States', 'activism', 'compassion']],
#  '/talks/christiane_amanpour_how_to_seek_truth_in_the_era_of_fake_news': ['2017-09-20',
#   1386756,
#   ['algorithm', 'communication', 'democracy', 'global issues']],
#  '/talks/christopher_ategeka_how_adoption_worked_for_me': ['2017-08-27',
#   833999,
#   ['Africa', 'TED Fellows', 'children', 'family']],
#  '/talks/chuck_nice_a_funny_look_at_the_unintended_consequences_of_technology': ['2017-04-24',
#   467496,
#   ['AI', 'comedy', 'communication', 'computers']],
#  '/talks/cleo_wade_want_to_change_the_world_start_by_being_brave_enough_to_care': ['2017-11-01',
#   1209886,
#   ['art', 'communication', 'creativity', 'goal-setting']],
#  '/talks/cynthia_erivo_natural_woman_and_johnny_and_donna': ['2017-04-24',
#   124357,
#   ['live music', 'music', 'performance', 'piano']],
#  '/talks/daan_roosegaarde_a_smog_vacuum_cleaner_and_other_magical_city_designs': ['2017-04-24',
#   984032,
#   ['architecture', 'environment', 'art', 'creativity']],
#  '/talks/damon_davis_what_i_saw_at_the_ferguson_protests': ['2017-04-24',
#   1027875,
#   ['TED Fellows', 'activism', 'art', 'community']],
#  '/talks/dan_gartenberg_the_brain_benefits_of_deep_sleep_and_how_to_get_more_of_it': ['2017-06-06',
#   2326547,
#   ['Human body', 'TED Residency', 'brain', 'health']],
#  '/talks/daniel_engber_how_the_progress_bar_keeps_you_sane': ['2018-03-15',
#   122472,
#   ['Internet', 'computers', 'design', 'history']],
#  '/talks/daniel_susskind_3_myths_about_the_future_of_work_and_why_they_re_not_true': ['2017-12-28',
#   948851,
#   ['AI', 'algorithm', 'computers', 'economics']],
#  '/talks/danielle_wood_how_we_can_use_space_technology_to_improve_life_on_earth': ['2017-11-16',
#   926408,
#   ['exploration', 'humanity', 'innovation', 'science']],
#  '/talks/danny_hillis_exploring_options_for_solar_geoengineering': ['2017-04-24',
#   529632,
#   ['Anthropocene', 'climate change', 'curiosity', 'future']],
#  '/talks/dao_nguyen_what_makes_something_go_viral': ['2017-10-17',
#   1151809,
#   ['Internet', 'communication', 'creativity', 'culture']],
#  '/talks/david_baron_you_owe_it_to_yourself_to_experience_a_total_solar_eclipse': ['2017-07-08',
#   1650599,
#   ['Moon', 'Sun', 'TEDx', 'astronomy']],
#  '/talks/david_brenner_a_new_weapon_in_the_fight_against_superbugs': ['2017-04-24',
#   1006843,
#   ['bacteria', 'health', 'illness', 'innovation']],
#  '/talks/david_katz_the_surprising_solution_to_ocean_plastic': ['2017-12-06',
#   995046,
#   ['business', 'innovation', 'oceans', 'plastic']],
#  '/talks/david_lee_why_jobs_of_the_future_won_t_feel_like_work': ['2017-07-20',
#   1631506,
#   ['business', 'creativity', 'future', 'innovation']],
#  '/talks/david_miliband_the_refugee_crisis_is_a_test_of_our_character': ['2017-04-24',
#   1290611,
#   ['TED Books', 'activism', 'big problems', 'children']],
#  '/talks/david_rockwell_the_hidden_ways_stairs_shape_your_life': ['2018-03-15',
#   92855,
#   ['emotions', 'history', 'design', 'title']],
#  '/talks/david_titley_how_the_military_fights_climate_change': ['2017-04-24',
#   914678,
#   ['climate change', 'global issues', 'military', 'natural disaster']],
#  '/talks/david_whyte_a_lyrical_bridge_between_past_present_and_future': ['2017-04-24',
#   929810,
#   ['art', 'humanity', 'performance', 'personal growth']],
#  '/talks/deanna_van_buren_what_a_world_without_prisons_could_look_like': ['2017-11-01',
#   718653,
#   ['United States', 'justice system', 'prison', 'social change']],
#  '/talks/deborah_willis_and_hank_willis_thomas_a_mother_and_son_united_by_love_and_art': ['2017-11-02',
#   839548,
#   ['art', 'collaboration', 'communication', 'creativity']],
#  '/talks/devita_davison_how_urban_agriculture_is_transforming_detroit': ['2017-04-24',
#   957210,
#   ['agriculture', 'cities', 'community', 'culture']],
#  '/talks/dixon_chibanda_why_i_train_grandmothers_to_treat_depression': ['2017-11-01',
#   889778,
#   ['Africa', 'collaboration', 'communication', 'community']],
#  '/talks/drew_philp_my_500_house_in_detroit_and_the_neighbors_who_helped_me_rebuild_it': ['2017-11-16',
#   506176,
#   ['United States', 'cities', 'community', 'culture']],
#  '/talks/duarte_geraldino_what_we_re_missing_in_the_debate_about_immigration': ['2017-06-06',
#   1026234,
#   ['TED Residency', 'United States', 'community', 'family']],
#  '/talks/dustin_schroeder_how_we_look_kilometers_below_the_antarctic_ice_sheet': ['2017-04-23',
#   696509,
#   ['Antarctica', 'TEDx', 'aircraft', 'climate change']],
#  '/talks/edsel_salvana_the_dangerous_evolution_of_hiv': ['2017-08-27',
#   1000054,
#   ['HIV', 'TED Fellows', 'medical research', 'science']],
#  '/talks/elif_shafak_the_revolutionary_power_of_diverse_thought': ['2017-09-20',
#   1551293,
#   ['complexity', 'culture', 'democracy', 'global issues']],
#  '/talks/elizabeth_blackburn_the_science_of_cells_that_never_get_old': ['2017-04-24',
#   1401625,
#   ['DNA', 'aging', 'biology', 'biomechanics']],
#  '/talks/elizabeth_wayne_we_can_hack_our_immune_cells_to_fight_cancer': ['2017-04-24',
#   1174890,
#   ['Human body', 'TED Fellows', 'cancer', 'science']],
#  '/talks/emily_esfahani_smith_there_s_more_to_life_than_being_happy': ['2017-04-24',
#   3855526,
#   ['happiness', 'humanity', 'personal growth', 'psychology']],
#  '/talks/eric_dyer_the_forgotten_art_of_the_zoetrope': ['2016-11-11',
#   945440,
#   ['TEDx', 'animation', 'art', 'creativity']],
#  '/talks/erica_stone_academic_research_is_publicly_funded_why_isn_t_it_publicly_available': ['2016-10-28',
#   491779,
#   ['TEDx', 'United States', 'communication', 'education']],
#  '/talks/erin_marie_saltman_how_young_people_join_violent_extremist_groups_and_how_to_stop_them': ['2016-06-18',
#   1046127,
#   ['TEDx', 'security', 'social media', 'terrorism']],
#  '/talks/euna_lee_what_i_learned_as_a_prisoner_in_north_korea': ['2016-10-29',
#   2000064,
#   ['Asia', 'TEDx', 'United States', 'china']],
#  '/talks/eve_abrams_the_human_stories_behind_mass_incarceration': ['2017-11-01',
#   481690,
#   ['activism', 'community', 'family', 'inequality']],
#  '/talks/felice_belle_and_jennifer_murphy_how_we_became_sisters': ['2017-11-01',
#   582274,
#   ['friendship', 'humanity', 'personal growth', 'play']],
#  '/talks/francoise_mouly_the_stories_behind_the_new_yorker_s_iconic_covers': ['2017-03-08',
#   1063515,
#   ['TEDNYC', 'art', 'creativity', 'culture']],
#  '/talks/fredros_okumu_how_i_study_the_most_dangerous_animal_on_earth_the_mosquito': ['2017-08-27',
#   863884,
#   ['Africa', 'CRISPR', 'biology', 'disease']],
#  '/talks/g_t_bynum_a_republican_mayor_s_plan_to_replace_partisanship_with_policy': ['2017-02-09',
#   853103,
#   ['TEDx', 'collaboration', 'community', 'data']],
#  '/talks/gabriela_gonzalez_how_ligo_discovered_gravitational_waves_and_what_might_be_next': ['2017-04-24',
#   423441,
#   ['TED en Español', 'collaboration', 'discovery', 'innovation']],
#  '/talks/gautam_bhan_a_bold_plan_to_house_100_million_people': ['2017-12-10',
#   332627,
#   ['cities', 'engineering', 'india', 'infrastructure']],
#  '/talks/george_steinmetz_photos_of_africa_taken_from_a_flying_lawn_chair': ['2017-08-27',
#   396676,
#   ['Africa', 'adventure', 'aircraft', 'art']],
#  '/talks/giulia_enders_the_surprisingly_charming_science_of_our_gut': ['2017-05-04',
#   1874699,
#   ['Human body', 'TEDx', 'bacteria', 'health']],
#  '/talks/grace_kim_how_cohousing_can_make_us_happier_and_live_longer': ['2017-04-24',
#   1777950,
#   ['architecture', 'cities', 'community', 'design']],
#  '/talks/greg_gage_electrical_experiments_with_plants_that_count_and_communicate': ['2017-04-24',
#   1546866,
#   ['TED Fellows', 'biomechanics', 'communication', 'education']],
#  '/talks/gretchen_carlson_how_we_can_end_sexual_harassment_at_work': ['2017-11-01',
#   1286958,
#   ['activism', 'journalism', 'law', 'leadership']],
#  '/talks/gus_casely_hayford_the_powerful_stories_that_shaped_africa': ['2017-08-27',
#   1101880,
#   ['Africa', 'ancient world', 'culture', 'education']],
#  '/talks/guy_winch_how_to_fix_a_broken_heart': ['2017-04-24',
#   1753205,
#   ['compassion', 'depression', 'humanity', 'identity']],
#  '/talks/hadi_eldebek_how_artists_contribute_to_the_economy_and_how_we_can_support_them': ['2016-12-13',
#   728326,
#   ['TED Residency', 'arts', 'culture', 'education']],
#  '/talks/hannah_burckstummer_a_printable_flexible_organic_solar_cell': ['2017-12-28',
#   276182,
#   ['electricity', 'energy', 'innovation', 'pollution']],
#  '/talks/heather_lanier_good_and_bad_are_incomplete_stories_we_tell_ourselves': ['2017-10-04',
#   1584101,
#   ['children', 'disability', 'family', 'humanity']],
#  '/talks/helen_czerski_fun_home_experiments_that_teach_you_physics': ['2017-02-19',
#   1371695,
#   ['TEDx', 'physics', 'play', 'science']],
#  '/talks/helen_pearson_lessons_from_the_longest_study_on_human_development': ['2017-04-24',
#   1697643,
#   ['aging', 'children', 'communication', 'data']],
#  '/talks/howard_c_stevenson_how_to_resolve_racially_stressful_situations': ['2017-11-01',
#   804348,
#   ['TEDMED', 'United States', 'communication', 'community']],
#  '/talks/huang_yi_kuka_a_human_robot_dance_duet': ['2017-04-24',
#   358000,
#   ['art', 'cello', 'creativity', 'dance']],
#  '/talks/ike_ude_the_radical_beauty_of_africa_in_portraits': ['2017-08-27',
#   166484,
#   ['Africa', 'art', 'beauty', 'creativity']],
#  '/talks/ilona_stengel_the_role_of_human_emotions_in_science_and_research': ['2017-12-28',
#   876030,
#   ['creativity', 'innovation', 'science', 'ratings']],
#  '/talks/ines_hercovich_why_women_stay_silent_after_sexual_assault': ['2015-09-24',
#   412254,
#   ['Gender equality', 'TED en Español', 'TEDx', 'activism']],
#  '/talks/ingrid_betancourt_what_six_years_in_captivity_taught_me_about_fear_and_faith': ['2017-04-24',
#   698206,
#   ['South America', 'TED en Español', 'activism', 'fear']],
#  '/talks/irina_kareva_math_can_help_uncover_cancer_s_secrets': ['2017-12-28',
#   492356,
#   ['biology', 'health', 'innovation', 'math']],
#  '/talks/isaac_mizrahi_how_the_button_changed_fashion': ['2018-03-15',
#   83969,
#   ['design', 'fashion', 'history', 'ratings']],
#  '/talks/isabel_wilkerson_the_great_migration_and_the_power_of_a_single_decision': ['2017-11-01',
#   627353,
#   ['Slavery', 'United States', 'history', 'identity']],
#  '/talks/iyad_rahwan_what_moral_decisions_should_driverless_cars_make': ['2016-09-29',
#   994719,
#   ['AI', 'driverless cars', 'innovation', 'law']],
#  '/talks/jack_conte_how_artists_can_finally_get_paid_in_the_digital_age': ['2017-04-24',
#   1059077,
#   ['art', 'business', 'creativity', 'entrepreneur']],
#  '/talks/jackson_bird_how_to_talk_and_listen_to_transgender_people': ['2017-06-06',
#   1148849,
#   ['LGBT', 'TED Residency', 'Transgender', 'activism']],
#  '/talks/jacob_collier_a_one_man_audio_visual_viral_sensation': ['2017-04-24',
#   393880,
#   ['art', 'live music', 'music', 'performance']],
#  '/talks/jason_shen_looking_for_a_job_highlight_your_ability_not_your_experience': ['2017-11-28',
#   1269522,
#   ['TED Residency', 'business', 'decision-making', 'education']],
#  '/talks/javed_akhtar_the_gift_of_words': ['2017-12-17',
#   366108,
#   ['communication', 'culture', 'india', 'intelligence']],
#  '/talks/jennifer_granick_how_the_us_government_spies_on_people_who_protest_including_you': ['2017-04-23',
#   1120398,
#   ['Surveillance', 'TEDx', 'United States', 'activism']],
#  '/talks/jennifer_pluznick_you_smell_with_your_body_not_just_your_nose': ['2016-11-30',
#   1445713,
#   ['Human body', 'Senses', 'TEDMED', 'biology']],
#  '/talks/jim_yong_kim_doesn_t_everyone_deserve_a_chance_at_a_good_life': ['2017-04-24',
#   1583376,
#   ['Africa', 'Internet', 'big problems', 'business']],
#  '/talks/jimmy_lin_a_simple_new_blood_test_that_can_catch_cancer_early': ['2017-04-24',
#   1285238,
#   ['DNA', 'TED Fellows', 'biology', 'cancer']],
#  '/talks/joan_blades_and_john_gable_free_yourself_from_your_filter_bubbles': ['2017-11-02',
#   1104535,
#   ['Internet', 'collaboration', 'communication', 'community']],
#  '/talks/joel_jackson_a_vehicle_built_in_africa_for_africa': ['2017-08-27',
#   896865,
#   ['Africa', 'TED Fellows', 'business', 'design']],
#  '/talks/john_cary_how_architecture_can_create_dignity_for_all': ['2017-11-01',
#   790413,
#   ['architecture', 'collaboration', 'community', 'creativity']],
#  '/talks/jon_boogz_and_lil_buck_a_dance_to_honor_mother_earth': ['2017-04-24',
#   245589,
#   ['art', 'creativity', 'dance', 'performance']],
#  '/talks/jon_bowers_we_should_aim_for_perfection_and_stop_fearing_failure': ['2017-07-20',
#   1446847,
#   ['cars', 'failure', 'goal-setting', 'leadership']],
#  '/talks/jorge_ramos_why_journalists_have_an_obligation_to_challenge_power': ['2017-04-24',
#   465479,
#   ['TED en Español', 'democracy', 'government', 'immigration']],
#  '/talks/jose_andres_how_a_team_of_chefs_fed_puerto_rico_after_hurricane_maria': ['2017-10-27',
#   414959,
#   ['TEDx', 'community', 'compassion', 'food']],
#  '/talks/joseph_redmon_how_a_computer_learns_to_recognize_objects_instantly': ['2017-04-24',
#   1656417,
#   ['AI', 'algorithm', 'computers', 'sight']],
#  '/talks/judith_heumann_our_fight_for_disability_rights_and_why_we_re_not_done_yet': ['2016-10-21',
#   519206,
#   ['activism', 'community', 'disability', 'education']],
#  '/talks/julio_gil_future_tech_will_give_you_the_benefits_of_city_life_anywhere': ['2017-07-20',
#   1212980,
#   ['augmented reality', 'business', 'cities', 'collaboration']],
#  '/talks/jun_wang_how_digital_dna_could_help_you_make_better_health_choices': ['2017-04-24',
#   1145148,
#   ['DNA', 'Human body', 'biology', 'data']],
#  '/talks/justin_baldoni_why_i_m_done_trying_to_be_man_enough': ['2017-11-01',
#   2652005,
#   ['activism', 'children', 'communication', 'culture']],
#  '/talks/kamau_gachigi_success_stories_from_kenya_s_first_makerspace': ['2017-08-27',
#   951537,
#   ['Africa', 'business', 'collaboration', 'creativity']],
#  '/talks/karen_lloyd_this_deep_sea_mystery_is_changing_our_understanding_of_life': ['2017-10-04',
#   994646,
#   ['animals', 'biodiversity', 'biology', 'biosphere']],
#  '/talks/karoliina_korppoo_how_a_video_game_might_help_us_build_better_cities': ['2017-04-24',
#   1288549,
#   ['cities', 'design', 'future', 'infrastructure']],
#  '/talks/kasiva_mutua_how_i_use_the_drum_to_tell_my_story': ['2017-08-27',
#   544828,
#   ['Africa', 'TED Fellows', 'art', 'music']],
#  '/talks/kate_marvel_can_clouds_buy_us_more_time_to_solve_climate_change': ['2017-04-24',
#   1132741,
#   ['Anthropocene', 'biosphere', 'climate change', 'environment']],
#  '/talks/katrina_spade_when_i_die_recompose_me': ['2016-03-05',
#   1190810,
#   ['TEDx', 'architecture', 'bacteria', 'biosphere']],
#  '/talks/kaustav_dey_how_fashion_helps_us_express_who_we_are_and_what_we_stand_for': ['2017-11-14',
#   698286,
#   ['activism', 'communication', 'creativity', 'fashion']],
#  '/talks/kayla_briet_why_do_i_make_art_to_build_time_capsules_for_my_heritage': ['2017-04-24',
#   842712,
#   ['TED Fellows', 'art', 'community', 'creativity']],
#  '/talks/keller_rinaudo_how_we_re_using_drones_to_deliver_blood_and_save_lives': ['2017-08-27',
#   991622,
#   ['Africa', 'disease', 'drones', 'entrepreneur']],
#  '/talks/kevin_njabo_how_we_can_stop_africa_s_scientific_brain_drain': ['2017-08-27',
#   776501,
#   ['Africa', 'conservation', 'education', 'science']],
#  '/talks/kristen_marhaver_why_i_still_have_hope_for_coral_reefs': ['2017-04-24',
#   1209217,
#   ['TED Fellows', 'animals', 'biology', 'climate change']],
#  '/talks/kristin_poinar_what_s_hidden_under_the_greenland_ice_sheet': ['2017-04-24',
#   1653459,
#   ['Antarctica', 'NASA', 'climate change', 'data']],
#  '/talks/kyra_gaunt_how_the_jump_rope_got_its_rhythm': ['2018-03-15',
#   79207,
#   ['design', 'history', 'music', 'play']],
#  '/talks/lana_mazahreh_3_thoughtful_ways_to_conserve_water': ['2017-10-04',
#   953081,
#   ['activism', 'climate change', 'environment', 'future']],
#  '/talks/laolu_senbanjo_the_sacred_art_of_the_ori': ['2017-04-24',
#   890103,
#   ['Africa', 'art', 'beauty', 'creativity']],
#  '/talks/lauren_sallan_how_to_win_at_evolution_and_survive_a_mass_extinction': ['2017-04-24',
#   1010157,
#   ['TED Fellows', 'biodiversity', 'biology', 'fish']],
#  '/talks/leah_chase_and_pat_mitchell_an_interview_with_the_queen_of_creole_cuisine': ['2017-11-01',
#   941845,
#   ['activism', 'family', 'food', 'history']],
#  '/talks/leila_takayama_what_s_it_like_to_be_a_robot': ['2017-04-02',
#   896884,
#   ['TEDx', 'design', 'future', 'innovation']],
#  '/talks/leo_igwe_why_i_choose_humanism_over_faith': ['2017-08-27',
#   547149,
#   ['Africa', 'collaboration', 'community', 'faith']],
#  '/talks/lera_boroditsky_how_language_shapes_the_way_we_think': ['2017-11-01',
#   612978,
#   ['brain', 'cognitive science', 'communication', 'humanity']],
#  '/talks/levon_biss_mind_blowing_magnified_portraits_of_insects': ['2017-04-24',
#   1060790,
#   ['animals', 'art', 'creativity', 'insects']],
#  '/talks/lisa_feldman_barrett_you_aren_t_at_the_mercy_of_your_emotions_your_brain_creates_them': ['2017-12-06',
#   1905726,
#   ['Emotions', 'brain', 'humanity', 'personal growth']],
#  '/talks/liz_hajek_what_rivers_can_tell_us_about_the_earth_s_history': ['2014-03-02',
#   1291030,
#   ['TEDx', 'ancient world', 'climate change', 'environment']],
#  '/talks/liz_ogbu_what_if_gentrification_was_about_healing_communities_instead_of_displacing_them': ['2017-11-01',
#   526978,
#   ['architecture', 'collaboration', 'community', 'design']],
#  '/talks/lloyd_pendleton_the_housing_first_approach_to_homelessness': ['2016-11-30',
#   906149,
#   ['TEDMED', 'cities', 'community', 'humanity']],
#  '/talks/luma_mufleh_don_t_feel_sorry_for_refugees_believe_in_them': ['2017-04-24',
#   1558611,
#   ['children', 'global issues', 'humanity', 'identity']],
#  '/talks/luvvie_ajayi_get_comfortable_with_being_uncomfortable': ['2017-11-01',
#   2064177,
#   ['communication', 'fear', 'humanity', 'identity']],
#  '/talks/malika_whitley_how_the_arts_help_homeless_youth_heal_and_build': ['2017-11-28',
#   382463,
#   ['activism', 'arts', 'creativity', 'humanity']],
#  '/talks/manoush_zomorodi_how_boredom_can_lead_to_your_most_brilliant_ideas': ['2017-04-24',
#   1748930,
#   ['brain', 'cognitive science', 'communication', 'creativity']],
#  '/talks/manu_prakash_lifesaving_scientific_tools_made_of_paper': ['2017-04-24',
#   1275332,
#   ['TED Fellows', 'disease', 'health care', 'innovation']],
#  '/talks/marc_bamuthi_joseph_what_soccer_can_teach_us_about_freedom': ['2017-08-27',
#   636033,
#   ['TED Fellows', 'art', 'community', 'creativity']],
#  '/talks/marc_raibert_meet_spot_the_robot_dog_that_can_run_hop_and_open_doors': ['2017-04-24',
#   2401010,
#   ['demo', 'design', 'future', 'robots']],
#  '/talks/marco_alvera_the_surprising_ingredient_that_makes_businesses_work_better': ['2017-10-04',
#   930334,
#   ['business', 'decision-making', 'leadership', 'motivation']],
#  '/talks/margaret_gould_stewart_how_the_hyperlink_changed_everything': ['2018-03-15',
#   84139,
#   ['Internet', 'computers', 'design', 'history']],
#  '/talks/margaret_mitchell_how_we_can_build_ai_to_help_humans_not_hurt_us': ['2017-10-04',
#   815042,
#   ['AI', 'Google', 'algorithm', 'collaboration']],
#  '/talks/margrethe_vestager_the_new_age_of_corporate_monopolies': ['2017-09-20',
#   1273753,
#   ['Europe', 'business', 'corruption', 'economics']],
#  '/talks/mariano_sigman_and_dan_ariely_how_can_groups_make_good_decisions': ['2017-04-24',
#   1241382,
#   ['Debate', 'choice', 'collaboration', 'communication']],
#  '/talks/marily_oppezzo_want_to_be_more_creative_go_for_a_walk': ['2017-04-23',
#   1815170,
#   ['TEDx', 'communication', 'creativity', 'exercise']],
#  '/talks/martin_ford_how_we_ll_earn_money_in_a_future_without_jobs': ['2017-04-24',
#   1916278,
#   ['AI', 'algorithm', 'capitalism', 'computers']],
#  '/talks/martina_flor_the_secret_language_of_letter_design': ['2016-10-22',
#   364712,
#   ['TED en Español', 'TEDx', 'art', 'books']],
#  '/talks/matilda_ho_the_future_of_good_food_in_china': ['2017-04-24',
#   1181922,
#   ['TED Fellows', 'agriculture', 'china', 'entrepreneur']],
#  '/talks/matt_goldman_the_search_for_aha_moments': ['2017-10-17',
#   951599,
#   ['children', 'collaboration', 'communication', 'community']],
#  '/talks/matthias_mullenbeck_what_if_we_paid_doctors_to_keep_people_healthy': ['2017-11-26',
#   698852,
#   ['economics', 'health', 'health care', 'medical research']],
#  '/talks/mehdi_ordikhani_seyedlar_what_happens_in_your_brain_when_you_pay_attention': ['2017-04-24',
#   2376083,
#   ['AI', 'algorithm', 'brain', 'cognitive science']],
#  '/talks/mei_lin_neo_the_fascinating_secret_lives_of_giant_clams': ['2017-04-24',
#   1093484,
#   ['TED Fellows', 'animals', 'biology', 'conservation']],
#  '/talks/mennat_el_ghalid_how_fungi_recognize_and_infect_plants': ['2017-08-27',
#   525282,
#   ['TED Fellows', 'biodiversity', 'biology', 'communication']],
#  '/talks/michael_bierut_the_genius_of_the_london_tube_map': ['2018-03-15',
#   253996,
#   ['design', 'history', 'map', 'transportation']],
#  '/talks/michelle_knox_talk_about_your_death_while_you_re_still_healthy': ['2017-12-11',
#   1026637,
#   ['communication', 'death', 'family', 'life']],
#  '/talks/miho_janvier_lessons_from_a_solar_storm_chaser': ['2017-08-27',
#   977390,
#   ['NASA', 'Sun', 'TED Fellows', 'nature']],
#  '/talks/mike_gil_could_fish_social_networks_help_us_save_coral_reefs': ['2017-08-27',
#   759339,
#   ['Anthropocene', 'TED Fellows', 'animals', 'biology']],
#  '/talks/mike_kinney_a_pro_wrestler_s_guide_to_confidence': ['2017-07-20',
#   1046085,
#   ['business', 'creativity', 'humor', 'identity']],
#  '/talks/minda_dentler_what_i_learned_when_i_conquered_the_world_s_toughest_triathlon': ['2017-11-01',
#   773051,
#   ['disability', 'disease', 'goal-setting', 'motivation']],
#  '/talks/mindy_scheier_how_adaptive_clothing_empowers_people_with_disabilities': ['2017-11-14',
#   799014,
#   ['design', 'disability', 'fashion', 'humanity']],
#  '/talks/mohamad_jebara_this_company_pays_kids_to_do_their_math_homework': ['2017-12-11',
#   833628,
#   ['education', 'math', 'statistics', 'teaching']],
#  '/talks/musimbi_kanyoro_to_solve_the_world_s_biggest_problems_invest_in_women_and_girls': ['2017-11-01',
#   770828,
#   ['Gender equality', 'activism', 'business', 'community']],
#  '/talks/mwende_freequency_katwiwa_black_life_at_the_intersection_of_birth_and_death': ['2017-11-02',
#   703258,
#   ['activism', 'art', 'humanity', 'identity']],
#  '/talks/nabila_alibhai_why_people_of_different_faiths_are_painting_their_houses_of_worship_yellow': ['2017-08-27',
#   1048795,
#   ['activism', 'art', 'community', 'faith']],
#  '/talks/nadine_hachach_haram_how_augmented_reality_could_change_the_future_of_surgery': ['2017-11-01',
#   1090660,
#   ['Surgery', 'augmented reality', 'collaboration', 'communication']],
#  '/talks/naoko_ishii_an_economic_case_for_saving_the_planet': ['2017-09-20',
#   920716,
#   ['biodiversity', 'biosphere', 'climate change', 'collaboration']],
#  '/talks/naomi_klein_how_shocking_events_can_spark_positive_change': ['2017-09-20',
#   707906,
#   ['activism', 'big problems', 'climate change', 'collaboration']],
#  '/talks/naomi_mcdougall_jones_what_it_s_like_to_be_a_woman_in_hollywood': ['2016-11-19',
#   1030319,
#   ['Gender equality', 'TEDx', 'activism', 'business']],
#  '/talks/natsai_audrey_chieza_fashion_has_a_pollution_problem_can_biology_fix_it': ['2017-10-04',
#   982963,
#   ['bacteria', 'biology', 'biotech', 'creativity']],
#  '/talks/ndidi_nwuneli_the_role_of_faith_and_belief_in_modern_africa': ['2017-08-27',
#   458330,
#   ['Africa', 'collaboration', 'community', 'education']],
#  '/talks/niki_okuk_when_workers_own_companies_the_economy_is_more_resilient': ['2016-10-08',
#   1102945,
#   ['TEDx', 'business', 'capitalism', 'community']],
#  '/talks/nikki_webber_allen_don_t_suffer_from_your_depression_in_silence': ['2017-06-06',
#   1663193,
#   ['TED Residency', 'activism', 'community', 'depression']],
#  '/talks/nilay_kulkarni_a_life_saving_invention_that_prevents_human_stampedes': ['2018-01-24',
#   740678,
#   ['collaboration', 'creativity', 'data', 'design']],
#  '/talks/nina_dolvik_brochmann_and_ellen_stokken_dahl_the_virginity_fraud': ['2017-05-03',
#   956476,
#   ['Human body', 'TEDx', 'activism', 'communication']],
#  '/talks/niti_bhan_the_hidden_opportunities_of_the_informal_economy': ['2017-08-27',
#   1036907,
#   ['Africa', 'business', 'creativity', 'culture']],
#  '/talks/nnedi_okorafor_sci_fi_stories_that_imagine_a_future_africa': ['2017-08-27',
#   918289,
#   ['Africa', 'adventure', 'creativity', 'future']],
#  '/talks/noah_feldman_hamilton_vs_madison_and_the_birth_of_american_partisanship': ['2017-04-24',
#   1051215,
#   ['United States', 'government', 'history', 'politics']],
#  '/talks/noriko_arai_can_a_robot_pass_a_university_entrance_exam': ['2017-04-24',
#   1312771,
#   ['AI', 'education', 'intelligence', 'robots']],
#  '/talks/oluf_mi_taiwo_why_africa_must_become_a_center_of_knowledge_again': ['2017-08-27',
#   1006806,
#   ['Africa', 'agriculture', 'history', 'leadership']],
#  '/talks/olutimehin_adegbeye_who_belongs_in_a_city': ['2017-08-27',
#   1219274,
#   ['Africa', 'activism', 'cities', 'government']],
#  '/talks/paola_antonelli_the_3_000_year_history_of_the_hoodie': ['2018-03-15',
#   122270,
#   ['design', 'fashion', 'history', 'society']],
#  '/talks/paul_hessburg_why_wildfires_have_gotten_worse_and_what_we_can_do_about_it': ['2017-05-13',
#   1000855,
#   ['TEDx', 'United States', 'climate change', 'ecology']],
#  '/talks/paul_tasner_how_i_became_an_entrepreneur_at_66': ['2017-06-06',
#   1624534,
#   ['TED Residency', 'aging', 'business', 'entrepreneur']],
#  '/talks/per_espen_stoknes_how_to_transform_apocalypse_fatigue_into_action_on_global_warming': ['2017-09-20',
#   1000232,
#   ['Anthropocene', 'communication', 'climate change', 'nature']],
#  '/talks/peter_calthorpe_7_principles_for_building_better_cities': ['2017-04-24',
#   1408701,
#   ['architecture', 'design', 'future', 'infrastructure']],
#  '/talks/peter_ouko_how_i_earned_a_law_diploma_while_on_death_row': ['2017-08-27',
#   757430,
#   ['Africa', 'humanity', 'law', 'criminal justice']],
#  '/talks/petter_johansson_do_you_really_know_why_you_do_what_you_do': ['2016-11-11',
#   730140,
#   ['TEDx', 'choice', 'cognitive science', 'decision-making']],
#  '/talks/pierre_thiam_a_forgotten_ancient_grain_that_could_help_africa_prosper': ['2017-08-27',
#   1035443,
#   ['Africa', 'agriculture', 'farming', 'food']],
#  '/talks/prumsodun_ok_the_magic_of_khmer_classical_dance': ['2017-04-24',
#   1091366,
#   ['TED Fellows', 'art', 'beauty', 'creativity']],
#  '/talks/rabbi_lord_jonathan_sacks_how_we_can_face_the_future_without_fear_together': ['2017-04-24',
#   1642469,
#   ['community', 'fear', 'future', 'global issues']],
#  '/talks/radhika_nagpal_what_intelligent_machines_can_learn_from_a_school_of_fish': ['2017-04-24',
#   1095571,
#   ['AI', 'ants', 'fish', 'future']],
#  '/talks/raphael_arar_how_we_can_teach_computers_to_make_sense_of_our_emotions': ['2017-12-06',
#   547875,
#   ['AI', 'art', 'complexity', 'computers']],
#  '/talks/ray_dalio_how_to_build_a_company_where_the_best_ideas_win': ['2017-04-24',
#   2113466,
#   ['algorithm', 'business', 'collaboration', 'communication']],
#  '/talks/raymond_tang_be_humble_and_other_lessons_from_the_philosophy_of_water': ['2017-12-11',
#   1041377,
#   ['humanity', 'motivation', 'personal growth', 'philosophy']],
#  '/talks/rei_my_mama_black_banana': ['2017-10-17',
#   203995,
#   ['guitar', 'live music', 'music', 'performance']],
#  '/talks/richard_browning_how_i_built_a_jet_suit': ['2017-04-24',
#   1729689,
#   ['adventure', 'collaboration', 'demo', 'design']],
#  '/talks/richard_j_berry_a_practical_way_to_help_the_homeless_find_work_and_safety': ['2017-02-09',
#   1117610,
#   ['Homelessness', 'TEDx', 'cities', 'community']],
#  '/talks/robert_hakiza_refugees_want_empowerment_not_handouts': ['2017-08-27',
#   641735,
#   ['Africa', 'TED Fellows', 'community', 'global issues']],
#  '/talks/robert_muggah_the_biggest_risks_facing_cities_and_some_solutions': ['2017-09-20',
#   1039514,
#   ['Brazil', 'cities', 'climate change', 'data']],
#  '/talks/robin_hanson_what_would_happen_if_we_upload_our_brains_to_computers': ['2017-04-24',
#   1233079,
#   ['AI', 'computers', 'economics', 'future']],
#  '/talks/robin_steinberg_what_if_we_ended_the_injustice_of_bail': ['2018-04-10',
#   500881,
#   ['United States', 'activism', 'community', 'inequality']],
#  '/talks/rocio_lorenzo_want_a_more_innovative_company_hire_more_women': ['2017-10-04',
#   1082827,
#   ['business', 'collaboration', 'creativity', 'data']],
#  '/talks/ronald_sullivan_how_i_help_free_innocent_people_from_prison': ['2016-10-21',
#   770847,
#   ['TEDx', 'United States', 'inequality', 'justice system']],
#  '/talks/sally_kohn_what_we_can_do_about_the_culture_of_hate': ['2017-11-01',
#   846124,
#   ['community', 'compassion', 'culture', 'relationships']],
#  '/talks/sara_dewitt_3_fears_about_screen_time_for_kids_and_why_they_re_not_true': ['2017-04-24',
#   1362909,
#   ['children', 'communication', 'education', 'family']],
#  '/talks/sara_menker_a_global_food_crisis_may_be_only_a_decade_away': ['2017-08-27',
#   1297716,
#   ['Africa', 'agriculture', 'data', 'economics']],
#  '/talks/sarah_corbett_activism_needs_introverts': ['2016-11-17',
#   1020710,
#   ['TEDx', 'activism', 'art', 'community']],
#  '/talks/sauti_sol_the_rhythm_of_afrobeat': ['2017-08-27',
#   123600,
#   ['Africa', 'music', 'performance', 'vocals']],
#  '/talks/scott_galloway_how_amazon_apple_facebook_and_google_manipulate_our_emotions': ['2017-10-17',
#   2075814,
#   ['Brand', 'advertising', 'business', 'culture']],
#  '/talks/scott_williams_the_hidden_role_informal_caregivers_play_in_health_care': ['2017-11-28',
#   852645,
#   ['health', 'health care', 'humanity', 'illness']],
#  '/talks/sebastian_thrun_and_chris_anderson_the_new_generation_of_computers_is_programming_itself': ['2017-04-24',
#   1305933,
#   ['AI', 'algorithm', 'cancer', 'collaboration']],
#  '/talks/sethembile_msezane_living_sculptures_that_stand_for_history_s_truths': ['2017-08-27',
#   988116,
#   ['Africa', 'activism', 'art', 'community']],
#  '/talks/shameem_akhtar_to_learn_is_to_be_free': ['2017-11-01',
#   794499,
#   ['activism', 'children', 'education', 'gender']],
#  '/talks/sharon_terry_science_didn_t_understand_my_kids_rare_disease_until_i_decided_to_study_it': ['2016-11-30',
#   1223644,
#   ['Bioethics', 'DNA', 'TEDMED', 'biology']],
#  '/talks/shonda_rhimes_and_cyndi_stivers_the_future_of_storytelling': ['2017-04-24',
#   1059221,
#   ['creativity', 'culture', 'family', 'future']],
#  '/talks/simone_bianco_and_tom_zimmerman_the_wonderful_world_of_life_in_a_drop_of_water': ['2017-12-06',
#   738867,
#   ['beauty', 'biodiversity', 'biology', 'biosphere']],
#  '/talks/sinead_burke_why_design_should_include_everyone': ['2017-03-08',
#   1254030,
#   ['TEDNYC', 'design', 'disability', 'fashion']],
#  '/talks/sofi_tukker_awoo': ['2017-03-08',
#   1064991,
#   ['TEDNYC', 'live music', 'music', 'performance']],
#  '/talks/soka_moses_for_survivors_of_ebola_the_crisis_isn_t_over': ['2017-11-01',
#   528990,
#   ['Africa', 'TEDMED', 'disease', 'ebola']],
#  '/talks/sophie_andrews_the_best_way_to_help_is_often_just_to_listen': ['2017-11-01',
#   995172,
#   ['TEDMED', 'aging', 'communication', 'depression']],
#  '/talks/soyapi_mumba_medical_tech_designed_to_meet_africa_s_needs': ['2017-08-27',
#   832161,
#   ['Africa', 'HIV', 'Internet', 'TED Fellows']],
#  '/talks/stewart_brand_and_chris_anderson_mammoths_resurrected_geoengineering_and_other_thoughts_from_a_futurist': ['2017-04-24',
#   974876,
#   ['deextinction', 'environment', 'future', 'green']],
#  '/talks/stuart_duncan_how_i_use_minecraft_to_help_kids_with_autism': ['2017-04-22',
#   863967,
#   ['Autism spectrum disorder', 'TEDx', 'children', 'gaming']],
#  '/talks/su_kahumbu_how_we_can_help_hungry_kids_one_text_at_a_time': ['2017-08-27',
#   742354,
#   ['Africa', 'TED Fellows', 'agriculture', 'animals']],
#  '/talks/sue_jaye_johnson_what_we_don_t_teach_kids_about_sex': ['2017-06-06',
#   1702689,
#   ['Human body', 'TED Residency', 'children', 'humanity']],
#  '/talks/susan_david_the_gift_and_power_of_emotional_courage': ['2017-11-02',
#   2188379,
#   ['Emotions', 'communication', 'depression', 'happiness']],
#  '/talks/susan_pinker_the_secret_to_living_longer_may_be_your_social_life': ['2017-04-24',
#   2012661,
#   ['aging', 'brain', 'community', 'family']],
#  '/talks/susan_robinson_how_i_fail_at_being_disabled': ['2016-12-13',
#   1290614,
#   ['Blindness', 'TED Residency', 'disability', 'failure']],
#  '/talks/tanya_menon_the_secret_to_great_opportunities_the_person_you_haven_t_met_yet': ['2017-03-25',
#   1262321,
#   ['TEDx', 'collaboration', 'communication', 'community']],
#  '/talks/tapiwa_chiwewe_you_don_t_have_to_be_an_expert_to_solve_big_problems': ['2017-12-06',
#   1065565,
#   ['Africa', 'collaboration', 'data', 'goal-setting']],
#  '/talks/tara_houska_the_standing_rock_resistance_and_our_fight_for_indigenous_rights': ['2017-11-01',
#   431194,
#   ['activism', 'community', 'culture', 'government']],
#  '/talks/tara_winkler_why_we_need_to_end_the_era_of_orphanages': ['2016-05-24',
#   972665,
#   ['TEDx', 'activism', 'children', 'family']],
#  '/talks/teresa_njoroge_what_i_learned_serving_time_for_a_crime_i_didn_t_commit': ['2017-11-01',
#   1088882,
#   ['Africa', 'activism', 'corruption', 'inequality']],
#  '/talks/theo_e_j_wilson_a_black_man_goes_undercover_in_the_alt_right': ['2017-07-08',
#   1704955,
#   ['Internet', 'TEDx', 'United States', 'community']],
#  '/talks/tiffany_kagure_mugo_and_siphumeze_khundayi_how_to_have_a_healthier_positive_relationship_to_sex': ['2017-11-01',
#   887677,
#   ['Africa', 'communication', 'humanity', 'identity']],
#  '/talks/tiffany_watt_smith_the_history_of_human_emotions': ['2017-11-28',
#   1412736,
#   ['Emotions', 'communication', 'culture', 'history']],
#  '/talks/tim_ferriss_why_you_should_define_your_fears_instead_of_your_goals': ['2017-04-24',
#   4580518,
#   ['choice', 'fear', 'goal-setting', 'humanity']],
#  '/talks/tim_kruger_can_we_stop_climate_change_by_removing_co2_from_the_air': ['2017-04-24',
#   1125940,
#   ['Natural resources',
#    'alternative energy',
#    'climate change',
#    'electricity']],
#  '/talks/tito_deler_my_fine_reward': ['2017-11-14',
#   156143,
#   ['guitar', 'live music', 'music', 'performance']],
#  '/talks/titus_kaphar_can_art_amend_history': ['2017-04-24',
#   1205948,
#   ['art', 'history', 'identity', 'inequality']],
#  '/talks/tom_gruber_how_ai_can_enhance_our_memory_work_and_social_lives': ['2017-04-24',
#   1640473,
#   ['AI', 'collaboration', 'computers', 'intelligence']],
#  '/talks/tomas_saraceno_would_you_live_in_a_floating_city_in_the_sky': ['2017-04-24',
#   524644,
#   ['TED en Español', 'art', 'creativity', 'design']],
#  '/talks/touria_el_glaoui_inside_africa_s_thriving_art_scene': ['2017-08-27',
#   753764,
#   ['Africa', 'art', 'painting', 'photography']],
#  '/talks/tricia_wang_the_human_insights_missing_from_big_data': ['2016-09-29',
#   1417517,
#   ['TEDx', 'algorithm', 'behavioral economics', 'business']],
#  '/talks/tristan_harris_the_manipulative_tricks_tech_companies_use_to_capture_your_attention': ['2017-04-24',
#   2032196,
#   ['algorithm', 'design', 'product design', 'social media']],
#  '/talks/uldus_bakhtiozina_portraits_that_transform_people_into_whatever_they_want_to_be': ['2017-04-24',
#   880250,
#   ['TED Fellows', 'art', 'creativity', 'identity']],
#  '/talks/valarie_kaur_3_lessons_of_revolutionary_love_in_a_time_of_rage': ['2017-11-01',
#   1027014,
#   ['community', 'feminism', 'humanity', 'love']],
#  '/talks/victoria_pratt_how_judges_can_show_respect': ['2016-10-05',
#   1025151,
#   ['big problems', 'communication', 'compassion', 'culture']],
#  '/talks/vikram_sharma_how_quantum_physics_can_make_encryption_stronger': ['2017-12-10',
#   537936,
#   ['computers', 'data', 'encryption', 'future']],
#  '/talks/vittorio_loreto_need_a_new_idea_start_at_the_edge_of_what_is_known': ['2017-10-04',
#   687360,
#   ['creativity', 'curiosity', 'discovery', 'exploration']],
#  '/talks/vivek_maru_how_to_put_the_power_of_law_in_people_s_hands': ['2017-08-27',
#   908376,
#   ['activism', 'communication', 'community', 'global issues']],
#  '/talks/wale_oyejide_fashion_that_celebrates_african_strength_and_spirit': ['2017-08-27',
#   668794,
#   ['Africa', 'TED Fellows', 'art', 'beauty']],
#  '/talks/wanuri_kahiu_fun_fierce_and_fantastical_african_art': ['2017-04-24',
#   797580,
#   ['Africa', 'TED Fellows', 'art', 'creativity']],
#  '/talks/washington_wachira_for_the_love_of_birds': ['2017-08-27',
#   906287,
#   ['Africa', 'animals', 'beauty', 'biodiversity']],
#  '/talks/wendy_suzuki_the_brain_changing_benefits_of_exercise': ['2017-11-01',
#   2200791,
#   ['biology', 'brain', 'exercise', 'health']],
#  '/talks/wendy_woods_the_business_benefits_of_doing_good': ['2017-10-04',
#   973181,
#   ['business', 'data', 'economics', 'innovation']],
#  '/talks/xavier_de_kestelier_adventures_of_an_interplanetary_architect': ['2016-11-17',
#   1001458,
#   ['NASA', 'TEDx', 'architecture', 'creativity']],
#  '/talks/yasin_kakande_what_s_missing_in_the_global_debate_over_refugees': ['2018-04-10',
#   311917,
#   ['TED Fellows', 'government', 'history', 'humanity']],
#  '/talks/yvette_alberdingk_thijm_the_power_of_citizen_video_to_create_undeniable_truths': ['2017-04-07',
#   941529,
#   ['TEDx', 'activism', 'collaboration', 'communication']],
#  '/talks/zachariah_mampilly_how_protest_is_redefining_democracy_around_the_world': ['2017-08-27',
#   682409,
#   ['Africa', 'activism', 'corruption', 'democracy']],
#  '/talks/zeynep_tufekci_we_re_building_a_dystopia_just_to_make_people_click_on_ads': ['2017-09-20',
#   2070081,
#   ['AI', 'algorithm', 'business', 'consumerism']]}

# %%
# if I want the key's to be rows, pass orient = 'index'
data_dict = pd.from_dict(my_old_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-466-aa100c27ac94> in <module>()
#       1 # if I want the key's to be rows, pass orient = 'index'
# ----> 2 data_dict = pd.from_dict(my_old_data)
#
# AttributeError: module 'pandas' has no attribute 'from_dict'

# %%
data_dict.describe()

# %%
data_dict.head()

# %% [markdown]
# ## More Data
#
# There is data from a kaggle that incorporates similar things above, and I will use it to enrich my data.  I will also substitute using it now because I am still troubleshooting pulling data from ted.com

# %%
import pickle
#reading a pickle file
with open("url_list.pkl", 'rb') as picklef: 
    kag_url = pickle.load(picklef)

# %%
kag_url
# Out:
# 2288    https://www.ted.com/talks/deeyah_khan_what_we_...
# 2289    https://www.ted.com/talks/deepika_kurup_a_youn...
# 2290    https://www.ted.com/talks/sarah_parcak_help_di...
# 2291    https://www.ted.com/talks/alan_smith_why_we_re...
# 2292    https://www.ted.com/talks/eduardo_briceno_how_...
# 2293    https://www.ted.com/talks/sue_klebold_my_son_w...
# 2294    https://www.ted.com/talks/nagin_cox_what_time_...
# 2295    https://www.ted.com/talks/maurice_conti_the_in...
# 2296    https://www.ted.com/talks/thordis_elva_tom_str...
# 2297    https://www.ted.com/talks/joshua_smith_new_nan...
# 2298    https://www.ted.com/talks/jeff_speck_4_ways_to...
# 2299    https://www.ted.com/talks/aala_el_khani_what_i...
# 2300    https://www.ted.com/talks/miriam_zoila_perez_h...
# 2301    https://www.ted.com/talks/rodrigo_y_gabriela_a...
# 2302    https://www.ted.com/talks/amy_adele_hasinoff_h...
# 2303    https://www.ted.com/talks/lara_setrakian_3_way...
# 2304    https://www.ted.com/talks/salil_dudani_how_jai...
# 2305    https://www.ted.com/talks/grady_booch_don_t_fe...
# 2306    https://www.ted.com/talks/yuval_noah_harari_na...
# 2307    https://www.ted.com/talks/brittney_cooper_the_...
# 2308    https://www.ted.com/talks/jonathan_rossiter_a_...
# 2309    https://www.ted.com/talks/charity_wayua_a_few_...
# 2310    https://www.ted.com/talks/stacy_smith_the_data...
# 2311    https://www.ted.com/talks/ani_liu_smelfies_and...
# 2312    https://www.ted.com/talks/jeff_kirschner_this_...
# 2313    https://www.ted.com/talks/lux_narayan_what_i_l...
# 2314    https://www.ted.com/talks/kathy_hull_stories_f...
# 2315    https://www.ted.com/talks/sara_ramirez_and_mic...
# 2316    https://www.ted.com/talks/carrie_poppy_a_scien...
# 2317    https://www.ted.com/talks/megan_phelps_roper_i...
#                               ...
# 2437    https://www.ted.com/talks/robin_hanson_what_wo...
# 2438    https://www.ted.com/talks/carolyn_bertozzi_wha...
# 2439    https://www.ted.com/talks/laolu_senbanjo_the_s...
# 2440    https://www.ted.com/talks/niki_okuk_when_worke...
# 2441    https://www.ted.com/talks/wanuri_kahiu_fun_fie...
# 2442    https://www.ted.com/talks/tara_winkler_why_we_...
# 2443    https://www.ted.com/talks/noriko_arai_can_a_ro...
# 2444    https://www.ted.com/talks/jennifer_granick_how...
# 2445    https://www.ted.com/talks/chance_coughenour_ho...
# 2446    https://www.ted.com/talks/chetan_bhatt_dare_to...
# 2447    https://www.ted.com/talks/daan_roosegaarde_a_s...
# 2448    https://www.ted.com/talks/erin_marie_saltman_h...
# 2449    https://www.ted.com/talks/ray_dalio_how_to_bui...
# 2450    https://www.ted.com/talks/tomas_saraceno_would...
# 2451    https://www.ted.com/talks/benjamin_grant_what_...
# 2452    https://www.ted.com/talks/olutimehin_adegbeye_...
# 2453    https://www.ted.com/talks/caitlin_quattromani_...
# 2454    https://www.ted.com/talks/emily_esfahani_smith...
# 2455    https://www.ted.com/talks/alexander_wagner_wha...
# 2456    https://www.ted.com/talks/pierre_thiam_a_forgo...
# 2457    https://www.ted.com/talks/augie_picado_the_rea...
# 2458    https://www.ted.com/talks/helen_czerski_fun_ho...
# 2459    https://www.ted.com/talks/sethembile_msezane_l...
# 2460    https://www.ted.com/talks/jun_wang_how_digital...
# 2461    https://www.ted.com/talks/oluf_mi_taiwo_why_af...
# 2462    https://www.ted.com/talks/duarte_geraldino_wha...
# 2463    https://www.ted.com/talks/armando_azua_bustos_...
# 2464    https://www.ted.com/talks/radhika_nagpal_what_...
# 2465    https://www.ted.com/talks/theo_e_j_wilson_a_bl...
# 2466    https://www.ted.com/talks/karoliina_korppoo_ho...
# Name: url, Length: 179, dtype: object

# %%
#Creating a list of all the ted vides
data = {}
count=0
tot_views=[]
proxy = proxies
for i in kag_url:
    time.sleep(30)
    count+=1
    response = rq.get(i, proxy)
    web_page = response.text
    webpage = soup(web_page,"lxml")
    date = getDate(webpage)
    tag_list = Cleanup(webpage)
    tot_views = get_Views(webpage)
    ratings = get_ratings(webpage)
    data[i] = [date,tot_views,tag_list,ratings]
    if count == 20 or count == 40 or count == 60 or count == 80:
        time.sleep(10)
        if count ==20:proxy = proxies
        if count ==40: proxy = prox2
        if count ==60: proxy = prox4
        if count ==80: 
            proxy = prox3
            count = 0

# %%
with open('test_data.pkl', 'wb') as picklefile:
    pickle.dump(data, picklefile)

# %%
# Out:
# 179
