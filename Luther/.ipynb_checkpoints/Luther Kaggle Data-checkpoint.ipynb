# %% [markdown]
# ## Luther Kaggle Data
#
# I am working on this data concurrently with troubleshooting my webscraping code.  I will either use this data to enrich the data I pulled or as a substitute whilst still waiting for the code to finsh running.
#
# The first section below will be involving only the main ted data.  I will be making the assumption that the view maturity of a video will be a year after its release.  I will store all data that has not been published for more than a year in its own df, and webscrape the current views to be used as an out-of-sample test set for my model.

# %%
import pandas as pd
import numpy as np
import math
import re
import time
from datetime import *
import dateutil.parser
# %matplotlib inline
# %config InlineBackend.figure_format = 'png'
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 400

# %%
#Reading in data
data = pd.read_csv('ted_main.csv')

# %%
#Exploring data types
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2550 entries, 0 to 2549
# Data columns (total 17 columns):
# comments              2550 non-null int64
# description           2550 non-null object
# duration              2550 non-null int64
# event                 2550 non-null object
# film_date             2550 non-null int64
# languages             2550 non-null int64
# main_speaker          2550 non-null object
# name                  2550 non-null object
# num_speaker           2550 non-null int64
# published_date        2550 non-null int64
# ratings               2550 non-null object
# related_talks         2550 non-null object
# speaker_occupation    2544 non-null object
# tags                  2550 non-null object
# title                 2550 non-null object
# url                   2550 non-null object
# views                 2550 non-null int64
# dtypes: int64(7), object(10)
# memory usage: 338.8+ KB

# %%
data.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# 1           Al Gore: Averting the climate crisis            1      1151367060
# 2                  David Pogue: Simplicity sells            1      1151367060
# 3             Majora Carter: Greening the ghetto            1      1151367060
# 4  Hans Rosling: The best stats you've ever seen            1      1151440680
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2  [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3  [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4  [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
#
#                                        related_talks  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 1  [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 2  [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 3  [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 4  [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
#
#                      speaker_occupation  \
# 0                       Author/educator
# 1                      Climate advocate
# 2                  Technology columnist
# 3    Activist for environmental justice
# 4  Global health expert; data visionary
#
#                                                 tags  \
# 0  ['children', 'creativity', 'culture', 'dance',...
# 1  ['alternative energy', 'cars', 'climate change...
# 2  ['computers', 'entertainment', 'interface desi...
# 3  ['MacArthur grant', 'activism', 'business', 'c...
# 4  ['Africa', 'Asia', 'Google', 'demo', 'economic...
#
#                              title  \
# 0      Do schools kill creativity?
# 1      Averting the climate crisis
# 2                 Simplicity sells
# 3              Greening the ghetto
# 4  The best stats you've ever seen
#
#                                                  url     views
# 0  https://www.ted.com/talks/ken_robinson_says_sc...  47227110
# 1  https://www.ted.com/talks/al_gore_on_averting_...   3200520
# 2  https://www.ted.com/talks/david_pogue_says_sim...   1636292
# 3  https://www.ted.com/talks/majora_carter_s_tale...   1697550
# 4  https://www.ted.com/talks/hans_rosling_shows_t...  12005869

# %%
def CleanCols(df):
    df.drop('url', axis=1, inplace = True)
    df.drop('description', axis=1, inplace = True)
    df.drop('name', axis=1, inplace = True)
    data['published_date'] = data['published_date'].apply(lambda x: datetime.fromtimestamp(x).date())
    data['film_date'] = data['film_date'].apply(lambda x: datetime.fromtimestamp(x).date())
    data['days_online'] = data['published_date'].apply(lambda x: ((dateutil.parser.parse('9/22/2017').date()-x)))
    data['days_online'] = (data['days_online']/np.timedelta64(1, 'D')).astype(int)
    data['log_views'] = data['views'].apply(lambda x: math.log(x))
    data['duration'] = round(data['duration']/60,2)
    #Using log views to get a better model
    data['log_views'] = data['views'].apply(lambda x: math.log(x))
    data['languages'] = data['languages'].replace(0,1)
    return df

# %%
#Removing unnecessary columns
CleanCols(data)
# Out:
#       comments  duration           event   film_date  languages  \
# 0         4553     19.40         TED2006  2006-02-24         60
# 1          265     16.28         TED2006  2006-02-24         43
# 2          124     21.43         TED2006  2006-02-23         26
{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4     [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# 5     [{'id': 7, 'name': 'Funny', 'count': 1102}, {'...
# 6     [{'id': 3, 'name': 'Courageous', 'count': 477}...
# 7     [{'id': 9, 'name': 'Ingenious', 'count': 195},...
# 8     [{'id': 3, 'name': 'Courageous', 'count': 562}...
# 9     [{'id': 21, 'name': 'Unconvincing', 'count': 8...
# 10    [{'id': 3, 'name': 'Courageous', 'count': 169}...
# 11    [{'id': 1, 'name': 'Beautiful', 'count': 70}, ...
# 12    [{'id': 8, 'name': 'Informative', 'count': 188...
# 13    [{'id': 9, 'name': 'Ingenious', 'count': 1014}...
# 14    [{'id': 3, 'name': 'Courageous', 'count': 83},...
# 15    [{'id': 1, 'name': 'Beautiful', 'count': 1671}...
# 16    [{'id': 1, 'name': 'Beautiful', 'count': 1107}...
# 17    [{'id': 9, 'name': 'Ingenious', 'count': 321},...
# 18    [{'id': 1, 'name': 'Beautiful', 'count': 259},...
# 19    [{'id': 1, 'name': 'Beautiful', 'count': 104},...
# 20    [{'id': 9, 'name': 'Ingenious', 'count': 117},...
# 21    [{'id': 7, 'name': 'Funny', 'count': 2799}, {'...
# 22    [{'id': 8, 'name': 'Informative', 'count': 82}...
# 23    [{'id': 7, 'name': 'Funny', 'count': 780}, {'i...
# 24    [{'id': 3, 'name': 'Courageous', 'count': 654}...
# 25    [{'id': 9, 'name': 'Ingenious', 'count': 269},...
# 26    [{'id': 1, 'name': 'Beautiful', 'count': 333},...
# 27    [{'id': 7, 'name': 'Funny', 'count': 485}, {'i...
# 28    [{'id': 7, 'name': 'Funny', 'count': 1668}, {'...
# 29    [{'id': 7, 'name': 'Funny', 'count': 1728}, {'...
# ...                                                 ...
# 2520  [{'id': 23, 'name': 'Jaw-dropping', 'count': 2...
# 2521  [{'id': 8, 'name': 'Informative', 'count': 146...
# 2522  [{'id': 1, 'name': 'Beautiful', 'count': 85}, ...
# 2523  [{'id': 3, 'name': 'Courageous', 'count': 46},...
# 2524  [{'id': 24, 'name': 'Persuasive', 'count': 19}...
# 2525  [{'id': 10, 'name': 'Inspiring', 'count': 119}...
# 2526  [{'id': 22, 'name': 'Fascinating', 'count': 11...
# 2527  [{'id': 3, 'name': 'Courageous', 'count': 63},...
# 2528  [{'id': 9, 'name': 'Ingenious', 'count': 16}, ...
# 2529  [{'id': 9, 'name': 'Ingenious', 'count': 24}, ...
# 2530  [{'id': 2, 'name': 'Confusing', 'count': 2}, {...
# 2531  [{'id': 8, 'name': 'Informative', 'count': 64}...
# 2532  [{'id': 25, 'name': 'OK', 'count': 26}, {'id':...
# 2533  [{'id': 1, 'name': 'Beautiful', 'count': 29}, ...
# 2534  [{'id': 10, 'name': 'Inspiring', 'count': 46},...
# 2535  [{'id': 3, 'name': 'Courageous', 'count': 77},...
# 2536  [{'id': 3, 'name': 'Courageous', 'count': 45},...
# 2537  [{'id': 1, 'name': 'Beautiful', 'count': 484},...
# 2538  [{'id': 10, 'name': 'Inspiring', 'count': 50},...
# 2539  [{'id': 10, 'name': 'Inspiring', 'count': 73},...
# 2540  [{'id': 1, 'name': 'Beautiful', 'count': 15}, ...
# 2541  [{'id': 11, 'name': 'Longwinded', 'count': 29}...
# 2542  [{'id': 1, 'name': 'Beautiful', 'count': 41}, ...
# 2543  [{'id': 1, 'name': 'Beautiful', 'count': 13}, ...
# 2544  [{'id': 1, 'name': 'Beautiful', 'count': 9}, {...
# 2545  [{'id': 3, 'name': 'Courageous', 'count': 24},...
# 2546  [{'id': 22, 'name': 'Fascinating', 'count': 32...
# 2547  [{'id': 1, 'name': 'Beautiful', 'count': 14}, ...
# 2548  [{'id': 11, 'name': 'Longwinded', 'count': 3},...
# 2549  [{'id': 21, 'name': 'Unconvincing', 'count': 2...
#
#                                           related_talks  \
# 0     [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...
# 1     [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...
# 2     [{'id': 1725, 'hero': 'https://pe.tedcdn.com/i...
# 3     [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 4     [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
# 5     [{'id': 229, 'hero': 'https://pe.tedcdn.com/im...
# 6     [{'id': 22, 'hero': 'https://pe.tedcdn.com/ima...
# 7     [{'id': 750, 'hero': 'https://pe.tedcdn.com/im...
# 8     [{'id': 71, 'hero': 'https://pe.tedcdn.com/ima...
# 9     [{'id': 94, 'hero': 'https://pe.tedcdn.com/ima...
# 10    [{'id': 1749, 'hero': 'https://pe.tedcdn.com/i...
# 11    [{'id': 2228, 'hero': 'https://pe.tedcdn.com/i...
# 12    [{'id': 1153, 'hero': 'https://pe.tedcdn.com/i...
# 13    [{'id': 685, 'hero': 'https://pe.tedcdn.com/im...
# 14    [{'id': 2043, 'hero': 'https://pe.tedcdn.com/i...
# 15    [{'id': 2273, 'hero': 'https://pe.tedcdn.com/i...
# 16    [{'id': 2273, 'hero': 'https://pe.tedcdn.com/i...
# 17    [{'id': 1561, 'hero': 'https://pe.tedcdn.com/i...
# 18    [{'id': 2251, 'hero': 'https://pe.tedcdn.com/i...
# 19    [{'id': 640, 'hero': 'https://pe.tedcdn.com/im...
# 20    [{'id': 1913, 'hero': 'https://pe.tedcdn.com/i...
# 21    [{'id': 148, 'hero': 'https://pe.tedcdn.com/im...
# 22    [{'id': 144, 'hero': 'https://pe.tedcdn.com/im...
# 23    [{'id': 307, 'hero': 'https://pe.tedcdn.com/im...
# 24    [{'id': 217, 'hero': 'https://pe.tedcdn.com/im...
# 25    [{'id': 2237, 'hero': 'https://pe.tedcdn.com/i...
# 26    [{'id': 1276, 'hero': 'https://pe.tedcdn.com/i...
# 27    [{'id': 20, 'hero': 'https://pe.tedcdn.com/ima...
# 28    [{'id': 93, 'hero': 'https://pe.tedcdn.com/ima...
# 29    [{'id': 944, 'hero': 'https://pe.tedcdn.com/im...
# ...                                                 ...
# 2520  [{'id': 2592, 'hero': 'https://pe.tedcdn.com/i...
# 2521  [{'id': 2504, 'hero': 'https://pe.tedcdn.com/i...
# 2522  [{'id': 2826, 'hero': 'https://pe.tedcdn.com/i...
# 2523  [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 2524  [{'id': 652, 'hero': 'https://pe.tedcdn.com/im...
# 2525  [{'id': 1596, 'hero': 'https://pe.tedcdn.com/i...
# 2526  [{'id': 2606, 'hero': 'https://pe.tedcdn.com/i...
# 2527  [{'id': 2567, 'hero': 'https://pe.tedcdn.com/i...
# 2528  [{'id': 2673, 'hero': 'https://pe.tedcdn.com/i...
# 2529  [{'id': 2811, 'hero': 'https://pe.tedcdn.com/i...
# 2530  [{'id': 2774, 'hero': 'https://pe.tedcdn.com/i...
# 2531  [{'id': 2309, 'hero': 'https://pe.tedcdn.com/i...
# 2532  [{'id': 2474, 'hero': 'https://pe.tedcdn.com/i...
# 2533  [{'id': 1085, 'hero': 'https://pe.tedcdn.com/i...
# 2534  [{'id': 2511, 'hero': 'https://pe.tedcdn.com/i...
# 2535  [{'id': 2880, 'hero': 'https://pe.tedcdn.com/i...
# 2536  [{'id': 2625, 'hero': 'https://pe.tedcdn.com/i...
# 2537  [{'id': 2399, 'hero': 'https://pe.tedcdn.com/i...
# 2538  [{'id': 1246, 'hero': 'https://pe.tedcdn.com/i...
# 2539  [{'id': 2873, 'hero': 'https://pe.tedcdn.com/i...
# 2540  [{'id': 2655, 'hero': 'https://pe.tedcdn.com/i...
# 2541  [{'id': 2491, 'hero': 'https://pe.tedcdn.com/i...
# 2542  [{'id': 2873, 'hero': 'https://pe.tedcdn.com/i...
# 2543  [{'id': 2490, 'hero': 'https://pe.tedcdn.com/i...
# 2544  [{'id': 2873, 'hero': 'https://pe.tedcdn.com/i...
# 2545  [{'id': 2596, 'hero': 'https://pe.tedcdn.com/i...
# 2546  [{'id': 2491, 'hero': 'https://pe.tedcdn.com/i...
# 2547  [{'id': 2346, 'hero': 'https://pe.tedcdn.com/i...
# 2548  [{'id': 2512, 'hero': 'https://pe.tedcdn.com/i...
# 2549  [{'id': 2682, 'hero': 'https://pe.tedcdn.com/i...
#
#                                speaker_occupation  \
# 0                                 Author/educator
# 1                                Climate advocate
# 2                            Technology columnist
# 3              Activist for environmental justice
# 4            Global health expert; data visionary
# 5     Life coach; expert in leadership psychology
# 6                     Actor, comedian, playwright
# 7                                       Architect
# 8                Philosopher, cognitive scientist
# 9                                  Pastor, author
# 10          Co-founder, Architecture for Humanity
# 11                                      Filmmaker
# 12                 Epidemiologist, philanthropist
# 13              Human-computer interface designer
# 14                                 Tech visionary
# 15                                      Violinist
# 16                              Pianist, composer
# 17                             inventor, engineer
# 18                            Industrial designer
# 19                           Founder of Wikipedia
# 20                            Education visionary
# 21                           Humorist, web artist
# 22                  Blogger; cofounder, Six Apart
# 23                 Anthropologist, expert on love
# 24                           Playwright, activist
# 25                              Quantum physicist
# 26                         Evolutionary biologist
# 27                                      Economist
# 28                                         Writer
# 29                 Psychologist; happiness expert
# ...                                           ...
# 2520                   Futurist, social scientist
# 2521                           Chemical biologist
# 2522           Artist, musician, lawyer, activist
# 2523                                 Entrepreneur
# 2524                            Filmmaker, writer
# 2525   Child protection leader, activist, author
# 2526                                    AI expert
# 2527       Surveillance and cybersecurity counsel
# 2528                        Digital archaeologist
# 2529           Sociologist, human rights activist
# 2530                                       Artist
# 2531                            Policy researcher
# 2532                             Hedge fund chair
# 2533                                       Artist
# 2534                                       Author
# 2535                             Writer, activist
# 2536                             Marketing leader
# 2537                                       Author
# 2538                                    Economist
# 2539                                         Chef
# 2540                            Border specialist
# 2541                                    Physicist
# 2542                                       Artist
# 2543                          Genomics researcher
# 2544                       Historian, philosopher
# 2545                                   Journalist
# 2546                               Astrobiologist
# 2547                            Robotics engineer
# 2548                          Public intellectual
# 2549                                Game designer
#
#                                                    tags  \
# 0     ['children', 'creativity', 'culture', 'dance',...
# 1     ['alternative energy', 'cars', 'climate change...
# 2     ['computers', 'entertainment', 'interface desi...
# 3     ['MacArthur grant', 'activism', 'business', 'c...
# 4     ['Africa', 'Asia', 'Google', 'demo', 'economic...
# 5     ['business', 'culture', 'entertainment', 'goal...
# 6     ['Christianity', 'God', 'atheism', 'comedy', '...
# 7     ['architecture', 'collaboration', 'culture', '...
# 8     ['God', 'TED Brain Trust', 'atheism', 'brain',...
# 9     ['Christianity', 'God', 'culture', 'happiness'...
# 10    ['activism', 'architecture', 'collaboration', ...
# 11    ['TED Prize', 'art', 'culture', 'entertainment...
# 12    ['TED Prize', 'collaboration', 'disease', 'ebo...
# 13    ['demo', 'design', 'interface design', 'techno...
# 14    ['children', 'design', 'education', 'entrepren...
# 15    ['entertainment', 'music', 'performance', 'vio...
# 16    ['creativity', 'entertainment', 'music', 'perf...
# 17    ['MacArthur grant', 'alternative energy', 'des...
# 18    ['DNA', 'biology', 'creativity', 'design', 'in...
# 19    ['business', 'collaboration', 'culture', 'inve...
# 20    ['business', 'collaboration', 'culture', 'glob...
# 21    ['collaboration', 'comedy', 'community', 'cult...
# 22    ['business', 'communication', 'community', 'cu...
# 23    ['cognitive science', 'culture', 'evolution', ...
# 24    ['culture', 'entertainment', 'gender', 'global...
# 25    ['climate change', 'cosmos', 'culture', 'envir...
# 26    ['astronomy', 'biology', 'cognitive science', ...
# 27    ['business', 'cities', 'culture', 'economics',...
# 28    ['business', 'choice', 'consumerism', 'culture...
# 29    ['TED Brain Trust', 'brain', 'choice', 'cultur...
# ...                                                 ...
# 2520  ['AI', 'computers', 'economics', 'future', 'hu...
# 2521  ['biology', 'biomechanics', 'cancer', 'chemist...
# 2522  ['Africa', 'art', 'beauty', 'creativity', 'per...
# 2523  ['TEDx', 'business', 'capitalism', 'community'...
# 2524  ['Africa', 'TED Fellows', 'art', 'creativity',...
# 2525  ['TEDx', 'activism', 'children', 'family', 'po...
# 2526  ['AI', 'education', 'intelligence', 'robots', ...
# 2527  ['TEDx', 'United States', 'activism', 'democra...
# 2528  ['TEDx', 'ancient world', 'archaeology', 'cons...
# 2529  ['TEDx', 'community', 'humanity', 'identity', ...
# 2530  ['architecture', 'art', 'cities', 'creativity'...
# 2531  ['TEDx', 'security', 'social media', 'terroris...
# 2532  ['algorithm', 'business', 'collaboration', 'co...
# 2533  ['TED en Español', 'art', 'creativity', 'desig...
# 2534  ['TEDx', 'art', 'climate change', 'environment...
# 2535  ['Africa', 'activism', 'cities', 'government',...
# 2536  ['TEDx', 'communication', 'friendship', 'polit...
# 2537  ['happiness', 'humanity', 'personal growth', '...
# 2538  ['TEDx', 'business', 'corruption', 'economics'...
# 2539  ['Africa', 'agriculture', 'farming', 'food', '...
# 2540  ['business', 'capitalism', 'collaboration', 'e...
# 2541             ['TEDx', 'physics', 'play', 'science']
# 2542  ['Africa', 'activism', 'art', 'community', 'hi...
# 2543  ['DNA', 'Human body', 'biology', 'data', 'entr...
# 2544  ['Africa', 'agriculture', 'history', 'leadersh...
# 2545  ['TED Residency', 'United States', 'community'...
# 2546  ['Mars', 'South America', 'TED Fellows', 'astr...
# 2547  ['AI', 'ants', 'fish', 'future', 'innovation',...
# 2548  ['Internet', 'TEDx', 'United States', 'communi...
# 2549  ['cities', 'design', 'future', 'infrastructure...
#
#                                                   title     views  \
# 0                           Do schools kill creativity?  47227110
# 1                           Averting the climate crisis   3200520
# 2                                      Simplicity sells   1636292
# 3                                   Greening the ghetto   1697550
# 4                       The best stats you've ever seen  12005869
# 5                                  Why we do what we do  20685401
# 6                                     Letting go of God   3769987
# 7                Behind the design of Seattle's library    967741
# 8     Let's teach religion -- all religion -- in sch...   2567958
# 9                                     A life of purpose   3095993
# 10         My wish: A call for open-source architecture   1211416
# 11                        My wish: A global day of film    387877
# 12                      My wish: Help me stop pandemics    693341
# 13     The radical promise of the multi-touch interface   4531020
# 14                                 One Laptop per Child    358304
# 15                      An 11-year-old's magical violin   2702470
# 16                        Improvising on piano, aged 14   1628912
# 17                        Simple designs to save a life   1415724
# 18                   Organic design, inspired by nature   1074081
# 2534                          Benjamin Grant            1     2017-09-07
# 2535                     OluTimehin Adegbeye            1     2017-09-08
# 2536  Caitlin Quattromani and Lauran Arledge            2     2017-09-11
# 2537                    Emily Esfahani Smith            1     2017-09-12
# 2538                        Alexander Wagner            1     2017-09-12
# 2539                            Pierre Thiam            1     2017-09-13
# 2540                            Augie Picado            1     2017-09-14
# 2541                           Helen Czerski            1     2017-09-14
# 2542                      Sethembile Msezane            1     2017-09-15
# 2543                                Jun Wang            1     2017-09-18
# 2544                     Olúfẹ́mi Táíwò            1     2017-09-19
# 2545                        Duarte Geraldino            1     2017-09-19
# 2546                     Armando Azua-Bustos            1     2017-09-20
# 2547                          Radhika Nagpal            1     2017-09-21
# 2548                        Theo E.J. Wilson            1     2017-09-21
# 2549                       Karoliina Korppoo            1     2017-09-22
#
#                                                 ratings  \
# 2288  [{'id': 1, 'name': 'Beautiful', 'count': 96}, ...
# 2289  [{'id': 1, 'name': 'Beautiful', 'count': 430},...
# 2290  [{'id': 8, 'name': 'Informative', 'count': 410...
# 2291  [{'id': 8, 'name': 'Informative', 'count': 813...
# 2292  [{'id': 25, 'name': 'OK', 'count': 124}, {'id'...
# 2293  [{'id': 8, 'name': 'Informative', 'count': 426...
# 2294  [{'id': 3, 'name': 'Courageous', 'count': 144}...
# 2295  [{'id': 8, 'name': 'Informative', 'count': 251...
# 2296  [{'id': 10, 'name': 'Inspiring', 'count': 3442...
# 2297  [{'id': 7, 'name': 'Funny', 'count': 374}, {'i...
# 2298  [{'id': 1, 'name': 'Beautiful', 'count': 369},...
# 2299  [{'id': 1, 'name': 'Beautiful', 'count': 168},...
# 2300  [{'id': 8, 'name': 'Informative', 'count': 182...
# 2301  [{'id': 1, 'name': 'Beautiful', 'count': 152},...
# 2302  [{'id': 1, 'name': 'Beautiful', 'count': 104},...
# 2303  [{'id': 1, 'name': 'Beautiful', 'count': 296},...
# 2304  [{'id': 9, 'name': 'Ingenious', 'count': 92}, ...
# 2305  [{'id': 8, 'name': 'Informative', 'count': 189...
# 2306  [{'id': 21, 'name': 'Unconvincing', 'count': 2...
# 2307  [{'id': 8, 'name': 'Informative', 'count': 269...
# 2308  [{'id': 8, 'name': 'Informative', 'count': 152...
# 2309  [{'id': 10, 'name': 'Inspiring', 'count': 447}...
# 2310  [{'id': 24, 'name': 'Persuasive', 'count': 106...
# 2311  [{'id': 1, 'name': 'Beautiful', 'count': 535},...
# 2312  [{'id': 25, 'name': 'OK', 'count': 125}, {'id'...
# 2313  [{'id': 1, 'name': 'Beautiful', 'count': 161},...
# 2314  [{'id': 21, 'name': 'Unconvincing', 'count': 1...
# 2315  [{'id': 21, 'name': 'Unconvincing', 'count': 3...
# 2316  [{'id': 1, 'name': 'Beautiful', 'count': 243},...
# 2317  [{'id': 1, 'name': 'Beautiful', 'count': 48}, ...
# ...                                                 ...
# 2520  [{'id': 23, 'name': 'Jaw-dropping', 'count': 2...
# 2521  [{'id': 8, 'name': 'Informative', 'count': 146...
# 2522  [{'id': 1, 'name': 'Beautiful', 'count': 85}, ...
# 2523  [{'id': 3, 'name': 'Courageous', 'count': 46},...
# 2524  [{'id': 24, 'name': 'Persuasive', 'count': 19}...
# 2525  [{'id': 10, 'name': 'Inspiring', 'count': 119}...
# 2526  [{'id': 22, 'name': 'Fascinating', 'count': 11...
# 2527  [{'id': 3, 'name': 'Courageous', 'count': 63},...
# 2528  [{'id': 9, 'name': 'Ingenious', 'count': 16}, ...
# 2529  [{'id': 9, 'name': 'Ingenious', 'count': 24}, ...
# 2530  [{'id': 2, 'name': 'Confusing', 'count': 2}, {...
# 2531  [{'id': 8, 'name': 'Informative', 'count': 64}...
# 2532  [{'id': 25, 'name': 'OK', 'count': 26}, {'id':...
# 2533  [{'id': 1, 'name': 'Beautiful', 'count': 29}, ...
# 2534  [{'id': 10, 'name': 'Inspiring', 'count': 46},...
# 2535  [{'id': 3, 'name': 'Courageous', 'count': 77},...
# 2536  [{'id': 3, 'name': 'Courageous', 'count': 45},...
# 2537  [{'id': 1, 'name': 'Beautiful', 'count': 484},...
# 2538  [{'id': 10, 'name': 'Inspiring', 'count': 50},...
# 2539  [{'id': 10, 'name': 'Inspiring', 'count': 73},...
# 2540  [{'id': 1, 'name': 'Beautiful', 'count': 15}, ...
# 2541  [{'id': 11, 'name': 'Longwinded', 'count': 29}...
# 2542  [{'id': 1, 'name': 'Beautiful', 'count': 41}, ...
# 2543  [{'id': 1, 'name': 'Beautiful', 'count': 13}, ...
# 2544  [{'id': 1, 'name': 'Beautiful', 'count': 9}, {...
# 2545  [{'id': 3, 'name': 'Courageous', 'count': 24},...
# 2546  [{'id': 22, 'name': 'Fascinating', 'count': 32...
# 2547  [{'id': 1, 'name': 'Beautiful', 'count': 14}, ...
# 2548  [{'id': 11, 'name': 'Longwinded', 'count': 3},...
# 2549  [{'id': 21, 'name': 'Unconvincing', 'count': 2...
#
#                                           related_talks  \
# 2288  [{'id': 2328, 'hero': 'https://pe.tedcdn.com/i...
# 2289  [{'id': 652, 'hero': 'https://pe.tedcdn.com/im...
# 2290  [{'id': 2558, 'hero': 'https://pe.tedcdn.com/i...
# 2291  [{'id': 2243, 'hero': 'https://pe.tedcdn.com/i...
# 2292  [{'id': 2330, 'hero': 'https://pe.tedcdn.com/i...
# 2293  [{'id': 2354, 'hero': 'https://pe.tedcdn.com/i...
# 2294  [{'id': 2543, 'hero': 'https://pe.tedcdn.com/i...
# 2295  [{'id': 1939, 'hero': 'https://pe.tedcdn.com/i...
# 2296  [{'id': 1951, 'hero': 'https://pe.tedcdn.com/i...
# 2297  [{'id': 1685, 'hero': 'https://pe.tedcdn.com/i...
# 2298  [{'id': 1718, 'hero': 'https://pe.tedcdn.com/i...
# 2299  [{'id': 1753, 'hero': 'https://pe.tedcdn.com/i...
# 2300  [{'id': 1789, 'hero': 'https://pe.tedcdn.com/i...
# 2301  [{'id': 2505, 'hero': 'https://pe.tedcdn.com/i...
# 2302  [{'id': 2547, 'hero': 'https://pe.tedcdn.com/i...
# 2303  [{'id': 2147, 'hero': 'https://pe.tedcdn.com/i...
# 2304  [{'id': 2447, 'hero': 'https://pe.tedcdn.com/i...
# 2305  [{'id': 2512, 'hero': 'https://pe.tedcdn.com/i...
# 
# 2520                   Futurist, social scientist
# 2521                           Chemical biologist
# 2522           Artist, musician, lawyer, activist
# 2523                                 Entrepreneur
# 2524                            Filmmaker, writer
# 2525   Child protection leader, activist, author
# 2526                                    AI expert
# 2527       Surveillance and cybersecurity counsel
# 2528                        Digital archaeologist
# 2529           Sociologist, human rights activist
# 2530                                       Artist
# 2531                            Policy researcher
# 2532                             Hedge fund chair
# 2533                                       Artist
# 2534                                       Author
# 2535                             Writer, activist
# 2536                             Marketing leader
# 2537                                       Author
# 2538                                    Economist
# 2539                                         Chef
# 2540                            Border specialist
# 2541                                    Physicist
# 2542                                       Artist
# 2543                          Genomics researcher
# 2544                       Historian, philosopher
# 2545                                   Journalist
# 2546                               Astrobiologist
# 2547                            Robotics engineer
# 2548                          Public intellectual
# 2549                                Game designer
#
#                                                    tags  \
# 2288  ['TEDNYC', 'United States', 'capitalism', 'chi...
# 2289  ['Africa', 'Slavery', 'TED Fellows', 'art', 'c...
# 2290  ['DNA', 'animals', 'biodiversity', 'biology', ...
# 2291  ['AI', 'brain', 'choice', 'future', 'history',...
# 2292  ['Internet', 'anthropology', 'communication', ...
# 2293  ['CRISPR', 'DNA', 'biology', 'biomechanics', '...
# 2294  ['TEDNYC', 'United States', 'community', 'demo...
# 2295  ['TEDx', 'brain', 'cancer', 'chemistry', 'heal...
# 2296  ['Blindness', 'brain', 'choice', 'fear', 'huma...
# 2297  ['adventure', 'curiosity', 'entertainment', 'e...
# 2298  ['communication', 'education', 'language', 'on...
# 2299  ['Internet', 'activism', 'communication', 'com...
# 2300  ['adventure', 'aging', 'humanity', 'identity',...
# 2301  ['PTSD', 'TEDMED', 'art', 'creativity', 'depre...
# 2302  ['business', 'collaboration', 'communication',...
# 2303  ['TEDx', 'art', 'beauty', 'creativity', 'cultu...
# 2304  ['behavioral economics', 'blockchain', 'busine...
# 2305  ['TEDMED', 'algorithm', 'communication', 'data...
# 2306  ['AI', 'algorithm', 'choice', 'computers', 'da...
# 2307  ['Islam', 'Middle East', 'TEDx', 'activism', '...
# 2308  ['TEDNYC', 'choice', 'communication', 'democra...
# 2309  ['biology', 'cars', 'cities', 'collaboration',...
# 2310  ['Africa', 'Asia', 'Europe', 'Foreign Policy',...
# 2311  ['TEDx', 'aging', 'art', 'beauty', 'cancer', '...
# 2312  ['TEDx', 'brain', 'communication', 'entertainm...
# 2313  ['art', 'live music', 'music', 'performance', ...
# 2314  ['TEDx', 'activism', 'art', 'beauty', 'creativ...
# 2315  ['Internet', 'Surveillance', 'TED Fellows', 'a...
# 2316  ['Slavery', 'TEDx', 'United States', 'children...
# 2317  ['big problems', 'collaboration', 'communicati...
# ...                                                 ...
# 2520  ['AI', 'computers', 'economics', 'future', 'hu...
# 2521  ['biology', 'biomechanics', 'cancer', 'chemist...
# 2522  ['Africa', 'art', 'beauty', 'creativity', 'per...
# 2523  ['TEDx', 'business', 'capitalism', 'community'...
# 2524  ['Africa', 'TED Fellows', 'art', 'creativity',...
# 2525  ['TEDx', 'activism', 'children', 'family', 'po...
# 2526  ['AI', 'education', 'intelligence', 'robots', ...
# 2527  ['TEDx', 'United States', 'activism', 'democra...
# 2528  ['TEDx', 'ancient world', 'archaeology', 'cons...
# 2529  ['TEDx', 'community', 'humanity', 'identity', ...
# 2530  ['architecture', 'art', 'cities', 'creativity'...
# 2531  ['TEDx', 'security', 'social media', 'terroris...
# 2532  ['algorithm', 'business', 'collaboration', 'co...
# 2533  ['TED en Español', 'art', 'creativity', 'desig...
# 2534  ['TEDx', 'art', 'climate change', 'environment...
# 2535  ['Africa', 'activism', 'cities', 'government',...
# 2536  ['TEDx', 'communication', 'friendship', 'polit...
# 2537  ['happiness', 'humanity', 'personal growth', '...
# 2538  ['TEDx', 'business', 'corruption', 'economics'...
# 2539  ['Africa', 'agriculture', 'farming', 'food', '...
# 2540  ['business', 'capitalism', 'collaboration', 'e...
# 2541             ['TEDx', 'physics', 'play', 'science']
# 2542  ['Africa', 'activism', 'art', 'community', 'hi...
# 2543  ['DNA', 'Human body', 'biology', 'data', 'entr...
# 2544  ['Africa', 'agriculture', 'history', 'leadersh...
# 2545  ['TED Residency', 'United States', 'community'...
# 2546  ['Mars', 'South America', 'TED Fellows', 'astr...
# 2547  ['AI', 'ants', 'fish', 'future', 'innovation',...
# 2548  ['Internet', 'TEDx', 'United States', 'communi...
# 2549  ['cities', 'design', 'future', 'infrastructure...
#
#                                                   title    views  days_online  \
# 2288                  America's forgotten working class  1077686          361
# 2289       A visual history of social dance in 25 moves   778810          360
# 2290   How we're harnessing nature's hidden superpowers  1211098          359
# 2291    Can we build AI without losing control over it?  2592561          358
# 2292         Technology hasn't changed love. Here's why  1593458          357
# 2293                 What you need to know about CRISPR  1400803          354
# 2294           Immigrant voices make democracy stronger   783649          353
# 2295        We can start winning the war against cancer   985203          352
# 2296        What reality are you creating for yourself?  2561564          351
# 2297                                 Ideas worth dating   792297          350
# 2298                  4 reasons to learn a new language  2173228          350
# 2299            How we talk about sexual assault online  1024139          347
# 2300                The beauty of what we'll never know  1477238          346
# 2301               Art can heal PTSD's invisible wounds   827933          345
# 2302        5 ways to lead in an era of constant change  1811178          344
# 2303            Ballroom dance that breaks gender roles   571009          343
# 2304  We've stopped trusting institutions and starte...  1307557          340
# 2305  A temporary tattoo that brings hospital care t...  1134472          339
# 2306  Machine intelligence makes human morals more i...  1194781          338
# 2307       Inside the mind of a former radical jihadist  1805897          337
# 2308  The unexpected challenges of a country's first...   859817          336
# 2309            What a driverless world could look like  2859109          333
# 2310        How the US should use its superpower status   851675          332
# 2311  How loss helped one artist find beauty in impe...  1134525          331
# 2312               Everything you hear on film is a lie  1236485          330
# 2313                        "St. James Infirmary Blues"   820295          329
# 2314                        Enough with the fear of fat  1594248          329
# 2315            Your smartphone is a civil rights issue  1307805          326
# 2316  How America's public schools keep kids in poverty  1181475          325
# 2317    Your company's data could help end world hunger   951340          324
# ...                                                 ...      ...          ...
# 2520  What would happen if we upload our brains to c...   840855           29
# 2521  What the sugar coating on your cells is trying...   727807           29
# 2522                        "The Sacred Art of the Ori"   636463           28
# 2523  When workers own companies, the economy is mor...   744793           25
# 2524            Fun, fierce and fantastical African art   522917           24
# 2525           Why we need to end the era of orphanages   656113           24
# 2526       Can a robot pass a university entrance exam?   773317           23
# 2527  How the US government spies on people who prot...   766721           22
# 2528    How your pictures can help reclaim lost history   539207           22
# 2529  Dare to refuse the origin myths that claim who...   857850           21
# 2530  A smog vacuum cleaner and other magical city d...   591131           17
# 2531  How young people join violent extremist groups...   665328           17
# 2532    How to build a company where the best ideas win  1070238           16
# 2533      Would you live in a floating city in the sky?   248411           15
# 2534         What it feels like to see Earth from space   646174           15
# 2535                             Who belongs in a city?   707788           14
# 2536  How our friendship survives our opposing politics   566101           11
# 2537              There's more to life than being happy  1009069           10
# 2538  What really motivates people to be honest in b...   621431           10
# 2539  A forgotten ancient grain that could help Afri...   527314            9
# 2540  The real reason manufacturing jobs are disappe...   613915            8
# 2541           The fascinating physics of everyday life   656791            8
# 2542  Living sculptures that stand for history's truths   542088            7
# 2543  How digital DNA could help you make better hea...   534824            4
# 2544  Why Africa must become a center of knowledge a...   418368            3
# 2545  What we're missing in the debate about immigra...   450430            3
# 2546                    The most Martian place on Earth   417470            2
# 2547  What intelligent machines can learn from a sch...   375647            1
# 2548       A black man goes undercover in the alt-right   419309            1
# 2549  How a video game might help us build better ci...   391721            0
#
#       log_views
# 2288  13.890327
# 2289  13.565522
# 2290  14.007038
# 2291  14.768157
# 2292  14.281417
# 2293  14.152556
# 2294  13.571716
# 2295  13.800603
# 2296  14.756129
# 2297  13.582692
# 2298  14.591724
# 2299  13.839363
# 2300  14.205685
# 2301  13.626688
# 2302  14.409488
# 2303  13.255160
# 2304  14.083671
# 2305  13.941678
# 2306  13.993473
# 2307  14.406568
# 2308  13.664475
# 2309  14.866021
# 2310  13.654960
# 2311  13.941725
# 2312  14.027783
# 2313  13.617419
# 2314  14.281913
# 2315  14.083861
# 2316  13.982274
# 2317  13.765627
# ...         ...
# 2520  13.642175
# 2521  13.497791
# 2522  13.363682
# 2523  13.520862
# 2524  13.167178
# 2525  13.394088
# 2526  13.558444
# 2527  13.549878
# 2528  13.197855
# 2529  13.662185
# 2530  13.289793
# 2531  13.408035
# 2532  13.883392
# 2533  12.422840
# 2534  13.378824
# 2535  13.469900
# 2536  13.246528
# 2537  13.824539
# 2538  13.339780
# 2539  13.175551
# 2540  13.327612
# 2541  13.395121
# 2542  13.203184
# 2543  13.189693
# 2544  12.944117
# 2545  13.017958
# 2546  12.941968
# 2547  12.836405
# 2548  12.946363
# 2549  12.878305
#
# [262 rows x 16 columns]

# %%
# Filtering out the test set
data = data[data['days_online'] >= 365]

# %% [markdown]
# ## Preliminary Plots
#
# Making some preliminary plots to get a better idea of what the data shows and to help decide what factors will be incorporated in the linear regression.  I will need to find a way to normalize the time component so we are comparing apples to apples.
#
# As seen below, log_views has the greatest correlation with the number of languages the transcript is available in and the amount of comments.  The former makes sense because the broader the audience, the more views it will get.  The latter (comments) is most likely true for 2 reasons. First, if someone leaves a comment, they will return to the page later to see other comments or respond to comments on their comment.  Either case counts as another 'view'.  Secondly, the comments can be an indicator about how people enjoyed the video and if a video is enjoyable.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Checking the data for correlations between variables
plt.savefig("test.png", format="png")
sns.heatmap(data.corr(), vmin=-1, vmax=1, cmap=('seismic'), annot = True)

# %%
#There really is no correlation between duration and number of speakers, or view count
fig = sns.lmplot(y="log_views", x="duration", data=play_df, hue = 'num_speaker', fit_reg = False)
fig = fig.set_axis_labels('duration', 'Log_Views')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-da2bf3d9214e> in <module>()
#       1 #There really is no correlation between duration and number of speakers, or view count
# ----> 2 fig = sns.lmplot(y="log_views", x="duration", data=play_df, hue = 'num_speaker', fit_reg = False)
#       3 fig = fig.set_axis_labels('duration', 'Log_Views')
#
# NameError: name 'play_df' is not defined

# %%
#Extracting the indeces for the highest view count for reference
four_highest = data[data.views>21000000].ratings.index
four_highest

# %%
data[['published_date','log_views']].set_index('published_date').plot()

# %%
#data[['comments','views']].set_index('published_date').plot()

# %%
data[['published_date','views']].set_index('published_date').plot()

# %%
fig, ax = plt.subplots(2, 1, figsize=(10, 9))  # 2 Rows, 1 Col

ax[0].plot(data['days_online'],data['views'])
ax[0].set_title('Views ')
ax[0].set_ylabel('Views')

ax[1].plot(data['days_online'], data['log_views'])
ax[1].set_xlabel('Days Online')
ax[1].set_ylabel('Log_Views')
ax[1].set_title('Comparison Between Views and Log Views');

# %% [markdown]
# ## Pulling out reactions
#
# Each video has its own ratings, or reactions the watchers have during or after the video.  The number of reactions were changed to proportions to normalize for each video, so we can compare the distribution of reactions based on number of views and other factors.

# %%
#Pulls the number of tags for a certain tag
def FindTag(tag, sl):
    hand = False
    count = 0
    for i in sl:
        if tag in i:
            hand = True
        elif hand == True:
            count = int(i.split('}')[0].strip())
            hand= False
    return count

# %%
# calling in each tag individually to run through the broken comment.  I am doing this so its easier to 
# join the dataframes later (and match the number to the correct column)
def CrackShell(string):
    tag_list=['Courageous', 'Beautiful', 'Confusing', 'Funny', 'Ingenious', 'Unconvincing', \
          'Longwinded', 'Informative', 'Inspiring', 'Fascinating', 'Persuasive', 'Jaw-dropping','Obnoxious']
    comment = string.split(':')
    emotes = []

    for i in tag_list:
        emotes.append(FindTag(i, comment))
    return emotes

# %%
#creates the reaction dictionary (emote_dict), and passes all possible reactions to the functions defined above
emote_dict = {}
tag_list=['Courageous', 'Beautiful', 'Confusing', 'Funny', 'Ingenious', 'Unconvincing', \
          'Longwinded', 'Informative', 'Inspiring', 'Fascinating', 'Persuasive', 'Jaw-dropping','Obnoxious']
for i in range(len(data.ratings)):
        emote_dict[i] = CrackShell(data.ratings[i])

# %%
#Turning dictionary into Dataframe
from pandas import DataFrame
emote_df = pd.DataFrame.from_dict(emote_dict, orient = 'index')

# %%
#adding column names to DF, then changing reaction count to reaction proportion, the last line is checking
# that the proportions do not exceed 1
emote_df.columns = tag_list
for i in range(0,len(emote_df.index)):
    emote_df.loc[i,:] = emote_df.loc[i,:] / emote_df.loc[i,:].sum()
emote_df.iloc[2286,:].sum()
# Out:
# 0.9999999999999999

# %%
#combining reaction DF with the original DF (data), then dropping the ratings column as it is no longer needed.
df= data.join(emote_df)
df= df.drop('ratings', axis=1)

# %%
emote_heat = emote_df.copy()
emote_heat['log_views'] = data['log_views']
sns.heatmap(emote_heat.corr(), cmap='seismic', vmin = -1, vmax=1)

# %% [markdown]
# ## Pulling out tags for dummy variables
#
# The ratings seen above some some interesting correlations, with correlations approximately between 0.2 and -0.4.  Are these correlations significant? Most of them are not.  Pushing further, we can get the tags associated with each video and use them to distinguish if the tags of a video affect the number of views.
#
# The goal is to pull out the tags associated with each video, then apply them as dummy variables in order to decide if they have a big affect on total views.

# %%
#Creating a list of unique tags
def uniqueitems(unfiltered):
    unique_list = []
    for x in unfiltered:
        if x not in unique_list and len(x)>4:
            unique_list.append(x)
    return unique_list

# %%
# Creating a dictionary similar to a default dictionary where the first row will be all 1s
def allthetags(extagaganza):
    tags = []
    dummy_dict = {}
    for i in range(len(extagaganza)):    
        tagrage = extagaganza[i].split('\'')
        taglen = len(tagrage)
        for k in range(1,taglen,2):
            tags.append(tagrage[k])
    uni_tag = uniqueitems(tags)
    for i in uni_tag:
        dummy_dict[i] = [1]
    return dummy_dict, uni_tag

# %%
#Taking the dictionary created in allthetags and assigning 0s or 1s in the appropriate lists to create categorical 
#column values
tag_dict={}
tag_dict, unitags = allthetags(data.tags)
for i in range(len(data.tags)):
    tagrage = data.tags[i].split('\'')
    taglen = len(tagrage)
    tags = [tagrage[k] for k in range(1,taglen,2)]
    # for loop  to fill in 1s and 0s for the dummy variables
    for d in tag_dict:
        if d in tags:
            tag_dict[d].append(1)
        else:
            tag_dict[d].append(0)

# %%
#Turns the dictionary into a DF, and drops first row because it was the initialization row
tag_df = pd.DataFrame(tag_dict) 
tag_df.drop(0, inplace=True)
tag_df.reset_index(drop=True, inplace = True)

# %%
#Dummy variable dataframe
inter_df = df.copy()
inter_df.drop('num_speaker',axis=1, inplace =True)
inter_df.drop('related_talks',axis=1, inplace =True)
inter_df.drop('speaker_occupation',axis=1, inplace =True)

# %%
tag_heat = tag_df.copy() 
tag_heat['views'] = data['views']
sns.heatmap(tag_heat.iloc[:,0:25].corr(), cmap = 'seismic', vmin=-2, vmax=2)

# %%
tag_df = inter_df.join(tag_df)

# %%
fig = sns.lmplot(y="views_pd", x="duration", data=tag_df, fit_reg = False)
fig = fig.set_axis_labels('Duration', 'Views')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-5c692861d109> in <module>()
# ----> 1 fig = sns.lmplot(y="views_pd", x="duration", data=tag_df, fit_reg = False)
#       2 fig = fig.set_axis_labels('Duration', 'Views')
#
# /anaconda3/lib/python3.6/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, size, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws)
#     550     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     551     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 552     data = data[cols]
#     553
#     554     # Initialize the grid
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2131         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2132             # either boolean or fancy integer index
# -> 2133             return self._getitem_array(key)
#    2134         elif isinstance(key, DataFrame):
#    2135             return self._getitem_frame(key)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2175             return self._take(indexer, axis=0, convert=False)
#    2176         else:
# -> 2177             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2178             return self._take(indexer, axis=1, convert=True)
#    2179
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1267                 if mask.any():
#    1268                     raise KeyError('{mask} not in index'
# -> 1269                                    .format(mask=objarr[mask]))
#    1270
#    1271                 return _values_from_object(indexer)
#
# KeyError: "['views_pd'] not in index"

# %%
tag_df.columns

# %%
# A list of all the tags for visual reference
len(['days_online','languages','Courageous', 'Beautiful', 'Confusing', 'Funny', 'Ingenious', 'Unconvincing', 'Longwinded', 'Informative', 'Inspiring', 'Fascinating', 'Persuasive', 'Jaw-dropping','Obnoxious',\
          'children', 'creativity', 'culture', 'dance', 'education', 'parenting', 'teaching', 'alternative energy', 'climate change', 'environment', 'global issues', 'science', 'sustainability', 'technology', 'computers', 'entertainment', 'interface design', 'media', 'music', 'performance', 'simplicity',\
           'software', 'MacArthur grant', 'activism', 'business', 'cities', 'green', 'inequality', 'politics', 'pollution', 'Africa', 'Google', 'economics', 'global development', 'health', 'statistics', 'visualizations', 'goal-setting', 'motivation', 'potential', 'psychology',\
           'Christianity', 'atheism', 'comedy', 'humor', 'religion', 'storytelling', 'architecture', 'collaboration', 'design', 'library', 'TED Brain Trust', 'brain', 'cognitive science', 'consciousness', 'evolution', 'philosophy','happiness',\
           'leadership', 'philanthropy', 'disaster relief', 'invention', 'open-source', 'TED Prize', 'movies', 'peace', 'social change', 'disease', 'ebola', 'entrepreneur', 'violin', 'wunderkind', 'youth', 'piano', 'engineering', 'industrial design', 'biology', 'nature', 'product design', 'science and art', 'wikipedia',\
           'community', 'communication', 'gender', 'relationships', 'theater', 'women', 'cosmos', 'physics', 'universe', 'astronomy', 'narcotics', 'choice', 'consumerism', 'marketing', 'decision-making', 'personal growth', 'cancer', 'aging', 'biotech', 'future', 'health care', 'investment', 'microfinance', 'poverty', 'telecom', 'transportation', 'corruption', 'military', 'policy',\
           'aircraft', 'flight', 'rocket science', 'exploration', 'sports', 'travel', 'photography', 'medicine', 'genetics', 'faith', 'illusion', 'robots', 'history', 'success', 'poetry', 'obesity', 'anthropology', 'language', 'complexity',\
           'evolutionary psychology', 'urban planning', 'innovation', 'United States', 'interview', 'performance art', 'materials', 'work-life balance', 'biodiversity', 'ecology', 'insects', 'animals', 'primates', 'typography', 'live music', 'singer', 'Brazil', 'animation', 'biomimicry', 'oceans', 'intelligence', 'biomechanics', 'online video', 'guitar', 'vocals', 'cello', 'china', 'memory', 'spoken word', 'composing', 'natural disaster',\
           'energy', 'museums', 'water', 'microsoft', 'virtual reality', 'women in business', 'Buddhism', 'New York', 'death', 'terrorism', 'Planets', 'adventure', 'mining', 'space', 'Bioethics', 'gaming', 'literature', 'prosthetics', 'books', 'sociology', 'violence', 'human origins', 'humanity', 'paleontology', 'asteroid', 'solar system', 'drones', 'solar energy', 'illness', 'depression', 'mental health', 'suicide', 'String theory', 'magic',\
           'compassion', 'empathy', 'writing', 'South America', 'world cultures', 'infrastructure', 'ancient world', 'garden', 'plants', 'telescopes', 'heart health', 'public health', 'big bang', 'bacteria', 'microbiology', 'submarine', 'society', 'archaeology', 'dinosaurs','beauty',\
           'plastic', 'Vaccines', 'conducting', 'family', 'trees', 'astrobiology', 'extraterrestrial life', 'introvert', 'personality', 'origami', 'dark matter', 'identity', 'nanoscale', 'geology', 'morality', 'presentation', 'crime',\
           'prison', 'democracy', 'smell', 'charter for compassion', 'social media', 'Senses', 'fashion', 'curiosity', 'programming', 'chemistry', 'shopping', 'body language', 'virus', 'birds', 'wind energy', 'extreme sports', 'prediction','productivity',\
           'TED Fellows', 'Natural resources', 'agriculture', 'india', 'neuroscience', 'money', 'state-building', 'Anthropocene', 'Europe', 'sight', 'Internet', 'government', 'advertising', 'sanitation', 'weather',\
           'big problems', 'rivers', 'Slavery', 'sexual violence', 'trafficking', 'Egypt', 'novel', 'feminism', 'TEDMED', 'Autism spectrum disorder', 'botany', 'mission blue', 'friendship','student',\
           'nuclear weapons', 'Surveillance', 'Islam', 'monkeys', 'Middle East', 'sound', 'population', 'manufacturing', 'TEDYouth', 'Gender equality', 'bullying', 'trust', 'sleep','journalism',\
           'cyborg', 'Foreign Policy', 'Surgery', 'medical research', 'protests', 'deextinction', 'disability',\
           'exoskeleton', 'nuclear energy', 'driverless cars', 'crowdsourcing', 'Brand', 'speech', 'failure', 'security', 'Blindness', 'Gender spectrum', 'glacier', 'mobility','TED en Español', 'public spaces',\
           'Human body', 'nonviolence', 'pharmaceuticals', 'molecular biology', 'behavioral economics', 'medical imaging', 'physiology', 'pregnancy', 'synthetic biology',\
           'hearing', 'Nobel prize', 'finance', 'algorithm', '3d printing', 'conservation', 'immigration', 'Criminal Justice','TED-Ed',\
           'privacy', 'microbes', 'machine learning', 'skateboarding', 'augmented reality', 'forensics', 'painting', 'pandemic',\
           'meditation', 'mindfulness', 'Syria', 'Transgender', 'testing', 'Debate', 'farming', 'cloud', 'TED Books', 'television','street art',\
           'Addiction', 'CRISPR', 'vulnerability', 'capitalism', 'refugees', 'grammar', 'resources', 'discovery', 'blockchain','TEDNYC','urban','TED Residency','biosphere'])

# %%
tag_df.loc[four_highest,['main_speaker','views',  'views_pd', 'duration']].sort_values('views', ascending=False)

# %% [markdown]
# ## Regression Analysis
#
# Below starts the linear regression and feature engineering section of the code.  All the code up to this point has been prepping exploring the data for this phase.  Exploring the data will help us validate and troubleshoot the model depending on the outcome.

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy

from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.cross_validation import train_test_split
from sklearn.cross_validation import KFold
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import SelectKBest
from sklearn.cross_validation import cross_val_score
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
y = tag_df.log_views
X = tag_df.drop(['event', 'film_date', 'main_speaker', 'meditation', 'published_date', 'tags', 'title', 'views', 'log_views'],1)
model1 = sm.OLS(y,X)
fit = model1.fit()
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_views   R-squared:                       0.709
# Model:                            OLS   Adj. R-squared:                  0.652
# Method:                 Least Squares   F-statistic:                     12.41
# Date:                Sun, 22 Apr 2018   Prob (F-statistic):          1.23e-321
# Time:                        18:14:08   Log-Likelihood:                -1315.5
# No. Observations:                2287   AIC:                             3385.
# Df Residuals:                    1910   BIC:                             5547.
# Df Model:                         376
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              271.205
# Skew:                           0.193   Prob(JB):                     1.28e-59
# Kurtosis:                       4.642   Cond. No.                     1.92e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.92e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
#Optimizing features based on SelectKBest, and the minimization of the mean squared error
est = LinearRegression()
mean_sc = 0
for i in range(2,40):
    X_new = SelectKBest(f_regression, k = i).fit(X,y)
    scores = cross_val_score(est, X_new , y, cv=10, scoring='neg_mean_squared_error')

    delta_sc = round(np.mean(-scores) - mean_sc, 5)
    if delta_sc >0 and mean_sc!=0:
        break  
    else:
        mean_sc = np.mean(-scores)
print(i,np.mean(-scores))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-0b40942e7192> in <module>()
#       4 for i in range(2,40):
#       5     X_new = SelectKBest(f_regression, k = i).fit(X,y)
# ----> 6     scores = cross_val_score(est, X_new , y, cv=10, scoring='neg_mean_squared_error')
#       7
#       8     delta_sc = round(np.mean(-scores) - mean_sc, 5)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py in cross_val_score(estimator, X, y, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#    1568
#    1569     """
# -> 1570     X, y = indexable(X, y)
#    1571
#    1572     cv = check_cv(cv, X, y, classifier=is_classifier(estimator))
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     227         else:
#     228             result.append(np.array(X))
# --> 229     check_consistent_length(*result)
#     230     return result
#     231
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     198     """
#     199
# --> 200     lengths = [_num_samples(X) for X in arrays if X is not None]
#     201     uniques = np.unique(lengths)
#     202     if len(uniques) > 1:
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in <listcomp>(.0)
#     198     """
#     199
# --> 200     lengths = [_num_samples(X) for X in arrays if X is not None]
#     201     uniques = np.unique(lengths)
#     202     if len(uniques) > 1:
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in _num_samples(x)
#     117         if len(x.shape) == 0:
#     118             raise TypeError("Singleton array %r cannot be considered"
# --> 119                             " a valid collection." % x)
#     120         return x.shape[0]
#     121     else:
#
# TypeError: Singleton array array(SelectKBest(k=2, score_func=<function f_regression at 0x1c2413f620>),
#       dtype=object) cannot be considered a valid collection.

# %%
model = sm.OLS(y, SelectKBest(f_regression, k = 5).fit(X,y))
fit = model.fit()
fit.summary()
#Do i need ot limit it to the number of total tags available? maybe 9, so it does not become overfitted
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#     398                 result = np.empty(len(values), dtype=object)
# --> 399                 result[:] = values
#     400             except ValueError:
#
# ValueError: could not broadcast input array from shape (2287,377) into shape (2287)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-ea4fa2104b94> in <module>()
# ----> 1 model = sm.OLS(y, SelectKBest(f_regression, k = 5).fit(pd.Series(X),y))
#       2 fit = model.fit()
#       3 fit.summary()
#       4 #Do i need ot limit it to the number of total tags available? maybe 9, so it does not become overfitted
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     262             else:
#     263                 data = _sanitize_array(data, index, dtype, copy,
# --> 264                                        raise_cast_failure=True)
#     265
#     266                 data = SingleBlockManager(data, index, fastpath=True)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    3275             raise Exception('Data must be 1-dimensional')
#    3276         else:
# -> 3277             subarr = _asarray_tuplesafe(data, dtype=dtype)
#    3278
#    3279     # This is to prevent mixed-type Series getting all casted to
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#     400             except ValueError:
#     401                 # we have a list-of-list
# --> 402                 result[:] = [tuple(x) for x in values]
#     403
#     404     return result
#
# ValueError: cannot copy sequence with size 377 to array axis with dimension 2287

# %%
#Residual Plot, is this a good model?!?!?
fit.resid.plot(style='o', figsize=(12,8));

# %%
fig = plt.figure(figsize=(12,8))
fig = sm.graphics.plot_regress_exog(model1, "languages", fig=fig)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-145-375e39b8ce0f> in <module>()
#       1 fig = plt.figure(figsize=(12,8))
# ----> 2 fig = sm.graphics.plot_regress_exog(fit, "languages", fig=fig)
#
# /anaconda3/lib/python3.6/site-packages/statsmodels/graphics/regressionplots.py in plot_regress_exog(results, exog_idx, fig)
#     185     fig = utils.create_mpl_fig(fig)
#     186
# --> 187     exog_name, exog_idx = utils.maybe_name_or_idx(exog_idx, results.model)
#     188     results = maybe_unwrap_results(results)
#     189
#
# /anaconda3/lib/python3.6/site-packages/statsmodels/graphics/utils.py in maybe_name_or_idx(idx, model)
#     112     else: # assume we've got a string variable
#     113         exog_name = idx
# --> 114         exog_idx = model.exog_names.index(idx)
#     115
#     116     return exog_name, exog_idx
#
# ValueError: 'languages' is not in list

# %% [markdown]
# ## Transcripts of Presentations
#
# Below is an analysis over the transcripts to see if any insight can be found.

# %%
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer
transcripts = pd.read_csv('transcripts.csv')
colors = sns.diverging_palette(10, 220, sep=80, n=7)

# %%
transcripts['wc'] = transcripts['transcript'].apply(lambda x: len(x.split(' ')))
transcripts['wpm'] = (transcripts['wc']/data['duration']).replace(0,1)
test_trans = transcripts.copy()
transcripts = transcripts.dropna()

test_trans['wpm'] = test_trans['wc']/test_df['duration']

# %%
test_trans.dropna(inplace = True)

# %%
url_list = []
url_list = test_trans.url

# %%
#Writing a pickle file
import pickle

with open('url_list.pkl', 'wb') as picklefile:
    pickle.dump(url_list, picklefile)

# %%
ran = len(transcripts.transcript)

# %%
transcripts['positivity_index'] = ['' for i in range(len(transcripts['transcript']))]
transcripts['polarity_score'] = ['' for i in range(len(transcripts['transcript']))]
for i in range(0,ran):
    text = transcripts['transcript'][i]
    pos = TextBlob(text)
    pos_val = pos.sentiment.polarity
    transcripts.loc[i,'polarity_score'] = pos_val
    if pos_val > 0:
        transcripts.loc[i,'positivity_index'] = 'positive'
    else:
        transcripts.loc[i,'positivity_index'] = 'negative'

# %%
pos = TextBlob(text)
pos.sentiment.polarity
# Out:
# 0.11102247275560158

# %%
trans_df = data.join(transcripts)
transcripts_df = tag_df.join(transcripts)

# %%
transcripts_df.wpm.min()
transcripts_df[transcripts_df['positivity_index'] == 'positive'].count()
# Out:
# comments             2249
# duration             2249
# event                2249
# film_date            2249
# languages            2249
# main_speaker         2249
# published_date       2249
# tags                 2249
# title                2249
# views                2249
# days_online          2249
# views_pd             2249
# log_views            2249
# views_norm           2249
# Courageous           2249
# Beautiful            2249
# Confusing            2249
# Funny                2249
# Ingenious            2249
# Unconvincing         2249
# Longwinded           2249
# Informative          2249
# Inspiring            2249
# Fascinating          2249
# Persuasive           2249
# Jaw-dropping         2249
# Obnoxious            2249
# 3d printing          2249
# Addiction            2249
# Africa               2249
#                      ...
# trees                2249
# trust                2249
# typography           2249
# universe             2249
# urban                2249
# urban planning       2249
# violence             2249
# violin               2249
# virtual reality      2249
# virus                2249
# visualizations       2249
# vocals               2249
# vulnerability        2249
# water                2249
# weather              2249
# wikipedia            2249
# wind energy          2249
# women                2249
# women in business    2249
# work-life balance    2249
# world cultures       2249
# writing              2249
# wunderkind           2249
# youth                2249
# transcript           2249
# url                  2249
# wc                   2249
# wpm                  2249
# positivity_index     2249
# polarity_score       2249
# Length: 394, dtype: int64

# %%
sns.heatmap(transcripts_df(['Courageous', 'Beautiful', 'Confusing', 'Funny', 'Ingenious', 'Unconvincing', 'Longwinded', 'Informative', 'Inspiring', 'Fascinating', 'Persuasive', 'Jaw-dropping','Obnoxious', 'log_views']).corr(), cmap=colors, annot = True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-d79fde6e1fbd> in <module>()
# ----> 1 sns.heatmap(transcripts_df(['Courageous', 'Beautiful', 'Confusing', 'Funny', 'Ingenious', 'Unconvincing', 'Longwinded', 'Informative', 'Inspiring', 'Fascinating', 'Persuasive', 'Jaw-dropping','Obnoxious', 'log_views']).corr(), cmap=colors, annot = True)
#
# TypeError: 'DataFrame' object is not callable

# %%
(transcripts_df.loc[:,['Courageous', 'Beautiful', 'Confusing', 'Funny', 'Ingenious', 'Unconvincing', 'Longwinded', 'Informative', 'Inspiring', 'Fascinating', 'Persuasive', 'Jaw-dropping','Obnoxious',]].sum())/len(transcripts_df.positivity_index)*100

# %%
['Courageous', 'Beautiful', 'Confusing', 'Funny', 'Ingenious', 'Unconvincing', 'Longwinded', 'Informative', 'Inspiring', 'Fascinating', 'Persuasive', 'Jaw-dropping']

# %%
fig = sns.pairplot(transcripts_df, vars=['Courageous', 'Beautiful', 'Confusing', 'Funny', 'Ingenious', 'Unconvincing', 'Longwinded', 'Informative', 'Inspiring', 'Fascinating', 'Persuasive', 'Jaw-dropping','Obnoxious', 'log_views'], hue = 'positivity_index')

# %%
fig = sns.lmplot(y="Informative", x="wpm", data=transcripts_df, hue = 'positivity_index',  fit_reg = False)

# %% [markdown]
# ## Out of Sample Data
#
# Below is reading and testing the model vs out of sample data.

# %%
#reading a pickle file
with open("test_data.pkl", 'rb') as picklefun: 
    ofs_dict = pickle.load(picklefun)

# %%
ofs_df = pd.DataFrame.from_dict(ofs_dict, orient = 'index')

# %%
ofs_df.reset_index(drop = True, inplace=True)
ofs_df.columns = ['date_pub', 'views','tags']
ofs_df['days_online'] = ofs_df['date_pub'].apply(lambda x: ((dateutil.parser.parse('9/22/2017').date()-x)))
ofs_df['days_online'] = (ofs_df['days_online']/np.timedelta64(1, 'D')).astype(int)
ofs_df['log_views'] = ofs_df['views'].apply(lambda x: math.log(x))

# %%
ofs_df
# Out:
#        date_pub    views                                               tags
# 0    2016-04-15  1304071              [Europe, Middle East, TEDx, activism]
# 1    2016-10-26  1051401      [bacteria, big problems, chemistry, children]
# 2    2016-02-15   894688     [Egypt, Middle East, South America, TED Prize]
# 3    2016-04-15  1546172           [TEDx, algorithm, animation, creativity]
# 4    2016-11-05  2499021      [TEDx, education, goal-setting, intelligence]
# 5    2016-11-30  3815275            [Guns, TEDMED, United States, activism]
# 6    2016-11-19  1729992                  [Mars, NASA, TEDx, United States]
# 7    2016-04-09  3302374                   [AI, TEDx, algorithm, computers]
# 8    2016-10-26  4450742  [activism, collaboration, communication, human...
# 9    2016-11-15   967258                [biology, biotech, cancer, disease]
# 10   2013-10-25  1602121                 [TEDx, architecture, cars, cities]
# 11   2016-02-14   970160               [Middle East, Syria, TEDx, children]
